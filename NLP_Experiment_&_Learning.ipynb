# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.15.0)

# %%
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.datasets import load_files
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from gensim.models import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import KeyedVectors
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences 
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SimpleRNN
from keras.layers import Dense, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.utils.np_utils import to_categorical
from keras.models import Model
from keras.engine import Input

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6eb43d1-186c-44ee-9e27-d4f3720c8f96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6eb43d1-186c-44ee-9e27-d4f3720c8f96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sa_data.csv to sa_data (4).csv

# %%
#Reading the data
data = pd.read_csv('sa_data.csv')

# %%
data.head()
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
#Preprocessing - removing unwanted characters, tokenization, stop-word removal
def clean_data(tweet):
    x = re.sub("[^a-zA-Z0-9]", " ",tweet) 
    x = x.lower().split()                             
    stops = set(stopwords.words("english"))                  
    words = [w for w in x if not w in stops]    
    return( " ".join(words))

# %%
data['text'] = data['text'].apply(lambda x: clean_data(x))
print(data['text'])
# Out:
# 0        rt nancyleegrahn everyone feel climate change ...
# 1        rt scottwalker catch full gopdebate last night...
# 2        rt tjmshow mention tamir rice gopdebate held c...
# 3        rt robgeorge carly fiorina trending hours deba...
# 4        rt danscavino gopdebate w realdonaldtrump deli...
#                                ...
# 13866    rt cappy yarbrough love see men never faced pr...
# 13867    rt georgehenryw thought huckabee exceeded expe...
# 13868    rt lrihendry tedcruz president always tell tru...
# 13869    rt jrehling gopdebate donald trump says time p...
# 13870    rt lrihendry tedcruz headed presidential debat...
# Name: text, Length: 13871, dtype: object

# %%
for i in range(len(data)):
    data['text'][i] = data['text'][i].replace('rt ','')

print(data['text'])
# Out:
# 0        nancyleegrahn everyone feel climate change que...
# 1        scottwalker catch full gopdebate last night sc...
# 2        tjmshow mention tamir rice gopdebate held clev...
# 3        robgeorge carly fiorina trending hours debate ...
# 4        danscavino gopdebate w realdonaldtrump deliver...
#                                ...
# 13866    cappy yarbrough love see men never faced pregn...
# 13867    georgehenryw thought huckabee exceeded expecta...
# 13868    lrihendry tedcruz president always tell truth ...
# 13869    jrehling gopdebate donald trump says time poli...
# 13870    lrihendry tedcruz headed presidential debates ...
# Name: text, Length: 13871, dtype: object

# %%
#Converting the dataframe into list
reviews = data['text'].tolist()
sentiment = data['sentiment'].tolist()

corpus = []
for i in range(len(reviews)):
    corpus.append(word_tokenize(reviews[i]))

# %%
corpus
# Out:
# [['nancyleegrahn',
#   'everyone',
#   'feel',
#   'climate',
#   'change',
#   'question',
#   'last',
#   'night',
#   'exactly',
#   'gopdebate'],
#  ['scottwalker',
#   'catch',
#   'full',
#   'gopdebate',
#   'last',
#   'night',
#   'scott',
#   'best',
#   'lines',
#   '90',
#   'seconds',
#   'walker16',
#   'http',
#   'co',
#   'zsff'],
#  ['tjmshow',
#   'mention',
#   'tamir',
#   'rice',
#   'gopdebate',
#   'held',
#   'cleveland',
#   'wow'],
#  ['robgeorge',
#   'carly',
#   'fiorina',
#   'trending',
#   'hours',
#   'debate',
#   'men',
#   'completed',
#   'gopdebate',
#   'says'],
#  ['danscavino',
#   'gopdebate',
#   'w',
#   'realdonaldtrump',
#   'delivered',
#   'highest',
#   'ratings',
#   'history',
#   'presidential',
#   'debates',
#   'trump2016',
#   'http',
#   'co'],
#  ['gregabbott',
#   'tx',
#   'tedcruz',
#   'first',
#   'day',
#   'rescind',
#   'every',
#   'illegal',
#   'executive',
#   'action',
#   'taken',
#   'barack',
#   'obama',
#   'gopdebate',
#   'foxnews'],
#  ['warriorwoman91',
#   'liked',
#   'happy',
#   'heard',
#   'going',
#   'moderator',
#   'anymore',
#   'gopdebate',
#   'megynkelly',
#   'https'],
#  ['going',
#   'msnbc',
#   'live',
#   'thomasaroberts',
#   'around',
#   '2',
#   'pm',
#   'et',
#   'gopdebate'],
#  ['deer',
#   'headlights',
#   'lizzwinstead',
#   'ben',
#   'carson',
#   'may',
#   'brain',
#   'surgeon',
#   'performed',
#   'lobotomy',
#   'gopdebate'],
#  ['nancyosborne180',
#   'last',
#   'night',
#   'debate',
#   'proved',
#   'gopdebate',
#   'batsask',
#   'badassteachersa',
#   'tbats',
#   'https',
#   'co',
#   'g2ggjy1bjd'],
#  ['jgreendc',
#   'realdonaldtrump',
#   'fairness',
#   'billclinton',
#   'owns',
#   'phrase',
#   'gopdebate'],
#  ['waynedupreeshow',
#   'woke',
#   'tweet',
#   'gopdebate',
#   'best',
#   'line',
#   'night',
#   'via',
#   'govmikehuckabee',
#   'http',
#   'co',
#   '6ov5hxhicv'],
#  ['reading',
#   'family',
#   'comments',
#   'great',
#   'gopdebate',
#   'http',
#   'co',
#   'giagjpygxz'],
#  ['arcticfox2016',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'ttfg7kycd9'],
#  ['pattonoswalt',
#   'loved',
#   'scott',
#   'walker',
#   'mark',
#   'harmon',
#   'romantic',
#   'rival',
#   'summer',
#   'school',
#   'look',
#   'gopdebate'],
#  ['hey',
#   'chrischristie',
#   'exploiting',
#   'tragedy',
#   '9',
#   '11',
#   'political',
#   'gain',
#   'rudygiulianigop',
#   'thing',
#   'gopdebate'],
#  ['carolcnn',
#   'donaldtrump',
#   'fire',
#   'comments',
#   'women',
#   'peterbeinasl',
#   'schaeffer',
#   'iwf',
#   'myrkiger',
#   'weigh',
#   'gopdebate',
#   'http'],
#  ['johncardillo',
#   'guess',
#   'speaking',
#   'time',
#   'gopdebate',
#   'foxnews',
#   'moderators',
#   '31',
#   '7',
#   'time',
#   'http',
#   'co',
#   '2wsut0c0lx'],
#  ['reason',
#   'comment',
#   'funny',
#   'case',
#   'ignorant',
#   'gop',
#   'tcot',
#   'reason',
#   'government',
#   'working',
#   'people',
#   'gopdebate'],
#  ['pamelageller',
#   'huckabee',
#   'paying',
#   'transgender',
#   'surgery',
#   'soldiers',
#   'sailors',
#   'airmen',
#   'make',
#   'country',
#   'safer',
#   'ha',
#   'gopdebate'],
#  ['chucknellis', 'cruz', 'class', 'amp', 'truth', 'gets', 'vote', 'gopdebate'],
#  ['mchamric',
#   'teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'nwgx8g8jwr'],
#  ['erinmallorylong',
#   'hate',
#   'planned',
#   'parenthood',
#   'women',
#   'hate',
#   'planned',
#   'parenthood',
#   'women',
#   'gopdebate'],
#  ['thekevinryder',
#   'gopdebate',
#   'vine',
#   'dabulldawg88',
#   'https',
#   'co',
#   'xkxvdradce'],
#  ['mrpooni',
#   'fox',
#   'news',
#   'trying',
#   'convince',
#   'us',
#   'young',
#   'black',
#   'americans',
#   'worried',
#   'isis',
#   'police',
#   'terrorism',
#   'gopdebate',
#   'http',
#   'co'],
#  ['gopdebate',
#   'rankings',
#   'worst',
#   'performance',
#   'rubio',
#   'kasich',
#   'christie',
#   'bush',
#   'trump',
#   'cruz',
#   'walker',
#   'paul',
#   'huckabee',
#   'carson'],
#  ['thebaxterbean',
#   'scott',
#   'walker',
#   'abortion',
#   'ban',
#   'allows',
#   'rapist',
#   'father',
#   'sue',
#   'emotional',
#   'distress',
#   'http',
#   'co',
#   'rhmvgumuir',
#   'gopdebate',
#   'badger'],
#  ['feministabulous',
#   'competition',
#   'moved',
#   'far',
#   'gay',
#   'rights',
#   'women',
#   'rights',
#   'worse',
#   'ever',
#   'g'],
#  ['mch7576',
#   'teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'pry2qpcwfu'],
#  ['hillaryclinton',
#   'watch',
#   'gopdebate',
#   'bet',
#   'feel',
#   'like',
#   'donating',
#   'democrat',
#   'right',
#   'http',
#   'co',
#   'pglqcqqgop',
#   'http',
#   'co',
#   'qp1e'],
#  ['fbhw',
#   'going',
#   'need',
#   'borrow',
#   'train',
#   'horn',
#   'next',
#   'gopdebate',
#   'little',
#   'bell',
#   'wimpy',
#   'hornmeansyouredone'],
#  ['lisavikingstad',
#   'ted',
#   'cruz',
#   'gopdebate',
#   'like',
#   'ted',
#   'cruz',
#   'bed',
#   'keep',
#   'confusingly',
#   'sad',
#   'look',
#   'face',
#   'refuse'],
#  ['first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'x6kuvskltf'],
#  ['socialmedia',
#   'first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'ogoyfnyikj'],
#  ['winesdaypodcast',
#   'update',
#   'foxnews',
#   'tech',
#   'failures',
#   'gopdebate',
#   'http',
#   'co',
#   'fgglf2j5hu',
#   'http',
#   'co',
#   'zw35dkuozi'],
#  ['amymek',
#   'torched',
#   'passed',
#   'gt',
#   'candycrowley',
#   'longer',
#   'famous',
#   'political',
#   'assassin',
#   'congratulations',
#   'megynkelly',
#   'u',
#   'wi'],
#  ['stockwizards3',
#   'trump',
#   'carson',
#   'ticket',
#   'would',
#   'win',
#   'landslide',
#   'realdonaldtrump',
#   'seanhannity',
#   'anncoulter',
#   'republican',
#   'potus',
#   'trump2016'],
#  ['kvxrdashian',
#   'jeb',
#   'bush',
#   'obama',
#   'fault',
#   'brother',
#   'obama',
#   'clean',
#   'mess',
#   'brother',
#   'made',
#   'gopdebate',
#   'http'],
#  ['ali',
#   'fox',
#   'news',
#   'gopdebate',
#   'primary',
#   'voters',
#   'none',
#   'wiser',
#   'policy',
#   'plans',
#   'folks',
#   'putting',
#   'forth',
#   'journalism'],
#  ['itsashlyperez',
#   'listening',
#   'fetty',
#   'wap',
#   'packing',
#   'true',
#   'american',
#   'gopdebate',
#   'doesthishashtagexpire'],
#  ['mgell',
#   'trump',
#   'cross',
#   'shrug',
#   'emoji',
#   'president',
#   'business',
#   'lego',
#   'movie',
#   'gopdebate'],
#  ['jamellemybelle',
#   'meanwhile',
#   'white',
#   'house',
#   'gopdebate',
#   'http',
#   'co',
#   'nouuut5hkq'],
#  ['rowdygentleman',
#   'planning',
#   'gopdebate',
#   'drinking',
#   'game',
#   'right',
#   'rowdy',
#   'gentleman'],
#  ['brownblaze', 'please', 'kkkorgop', 'gopdebate', 'http', 'co', 'yaqyac3uv3'],
#  ['trump',
#   'thinks',
#   'criticism',
#   'misogynistic',
#   'remarks',
#   'political',
#   'correctness',
#   'problem',
#   'nope',
#   'pervasive',
#   'sexism',
#   'problem',
#   'gopdebate'],
#  ['lekarmasucre',
#   'gopdebate',
#   'handled',
#   'blacklivesmatter',
#   'http',
#   'co',
#   '8zgdy6lpct'],
#  ['palmaceiahome1',
#   'goal',
#   'foxnews',
#   'last',
#   'night',
#   'take',
#   'trump',
#   'pave',
#   'way',
#   'rino',
#   'like',
#   'bush',
#   'kasich',
#   'gopdebate'],
#  ['philstockworld',
#   'live',
#   'chat',
#   'room',
#   'gopdebate',
#   'trump',
#   'futures',
#   'spy',
#   'nonfarmpayrolls',
#   'jobs',
#   'netflix',
#   'http',
#   'co',
#   '0k06sf81rq',
#   'http'],
#  ['danscavino',
#   'gopdebate',
#   'w',
#   'realdonaldtrump',
#   'delivered',
#   'highest',
#   'ratings',
#   'history',
#   'presidential',
#   'debates',
#   'trump2016',
#   'fox',
#   'say',
#   'thanks'],
#  ['gov',
#   'tweeted',
#   'govmikehuckabee',
#   'gopdebate',
#   'moment',
#   'saying',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'trans',
#   'servicemembers'],
#  ['ariannahuff', 'best', 'worst', 'gopdebate', 'http', 'co', 'yki30j7hho'],
#  ['megynkelly',
#   'chrisstirewalt',
#   'big',
#   'moments',
#   'randpaul',
#   'vs',
#   'chrischristie',
#   'realdonaldtrump',
#   'reaction',
#   'women',
#   'question',
#   'kellyfil'],
#  ['stylemom',
#   'question',
#   'hell',
#   'women',
#   'amp',
#   'body',
#   'parts',
#   'even',
#   'debate',
#   'foh',
#   'stop',
#   '1965',
#   'wtf',
#   'gopdebate'],
#  ['rushlimbaugh',
#   'americans',
#   'getting',
#   'beheaded',
#   'overseas',
#   'megynkelly',
#   'worried',
#   'whether',
#   'realdonaldtrump',
#   'calls',
#   'rosie',
#   'donnell',
#   'fat',
#   'gopdebate'],
#  ['chucknellis',
#   'defend',
#   'foxnews',
#   'far',
#   'fair',
#   'balanced',
#   'last',
#   'night',
#   'name',
#   'calling',
#   'juvenile',
#   'gopdebate'],
#  ['theskysgoneout',
#   'non',
#   'christians',
#   'gopdebate',
#   'god',
#   'questions',
#   'underline',
#   'little',
#   'anyone',
#   'really',
#   'cares',
#   'religious',
#   'minorities',
#   'chri'],
#  ['bipartisanism',
#   'gopdebate',
#   'response',
#   'blacklivesmatter',
#   'pathetic',
#   'http',
#   'co',
#   'ismxbrrm0h'],
#  ['factcheckdotorg',
#   'jebbush',
#   'said',
#   'cut',
#   'fl',
#   'taxes',
#   '19b',
#   'includes',
#   'cuts',
#   'estate',
#   'taxes',
#   'mandated',
#   'federal',
#   'law',
#   'gopdebate',
#   'ht'],
#  ['mydaughtersarmy',
#   'dear',
#   'gop',
#   'want',
#   'stop',
#   'abortions',
#   'gopdebate',
#   'http',
#   'co',
#   'rbl1t4ipx6'],
#  ['karrattipaul',
#   'join',
#   'isis',
#   'sign',
#   'death',
#   'warrant',
#   'signed',
#   'tedcruz',
#   'next',
#   'president',
#   'us',
#   'gopdebate',
#   'wakeupamerica',
#   'cruzcrew',
#   'htt'],
#  ['p0tus', 'gopdebate', 'closing', 'statements', 'http', 'co', 's15nlillso'],
#  ['amymek',
#   'status',
#   'single',
#   'broke',
#   'foxnews',
#   'last',
#   'night',
#   'goodbye',
#   'megynkelly',
#   'bretbaier',
#   'amp',
#   'chris',
#   'wallace',
#   'gopdebate',
#   'http'],
#  ['frankluntz',
#   'gopdebate',
#   '14',
#   'focus',
#   'groupers',
#   'said',
#   'favorable',
#   'view',
#   'trump',
#   '3',
#   'saw',
#   'positively',
#   'http'],
#  ['holly',
#   'renee',
#   'made',
#   'first',
#   'donation',
#   'carlyfiorina',
#   'impressed',
#   'gopdebate',
#   'performance',
#   'fiorina',
#   'http',
#   'co',
#   'jlfhfvz7st'],
#  ['thejimhughes',
#   'want',
#   'stop',
#   'sending',
#   'foreign',
#   'aid',
#   'places',
#   'burn',
#   'flag',
#   'staberkeley',
#   'gopdebate'],
#  ['frankthorpnbc',
#   'rand',
#   'paul',
#   'eye',
#   'roll',
#   'chris',
#   'christie',
#   'gopdebate',
#   'https',
#   'co',
#   'hf318qsowd'],
#  ['johnkasich',
#   'scrap',
#   'president',
#   'iran',
#   'deal',
#   'iran',
#   'get',
#   'nuke',
#   'kasich4us',
#   'gopdebate',
#   'http',
#   'co',
#   '9trzxonlzf'],
#  ['trying',
#   'decide',
#   'early',
#   'come',
#   'back',
#   'twitter',
#   'fulltime',
#   'gon',
#   'na',
#   'wait',
#   'closer',
#   'election',
#   'gopdebate',
#   'may',
#   'hooked'],
#  ['mspackyetti',
#   'donald',
#   'trump',
#   'campaign',
#   'reveals',
#   '1',
#   'important',
#   'thing',
#   'twitter',
#   'trolls',
#   'real',
#   'people',
#   'vote',
#   'scare',
#   'eve'],
#  ['bipartisanism',
#   'saying',
#   'worry',
#   'trump',
#   'never',
#   'elected',
#   'need',
#   'remember',
#   'elected',
#   'george',
#   'bush',
#   'twice',
#   'gopdebate',
#   'http'],
#  ['fox',
#   'news',
#   'gopdebate',
#   'agenda',
#   'promote',
#   'carly',
#   'never',
#   'mention',
#   'fired',
#   'hp',
#   'fiorina',
#   'amp',
#   'run',
#   'trump',
#   'race',
#   'http',
#   'co',
#   '9k1eujdfo7'],
#  ['hlllary',
#   'oh',
#   'one',
#   'thing',
#   'anyone',
#   'hear',
#   'anything',
#   'affordable',
#   'child',
#   'care',
#   'working',
#   'families',
#   'last',
#   'night',
#   'gopdebate'],
#  ['naughtybeyotch',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'wqnsupspkc'],
#  ['marthamaccallum',
#   'billhemmer',
#   'gopdebate',
#   'bill',
#   'martha',
#   'team',
#   'first',
#   'debate',
#   '2nd',
#   'debate',
#   'ambush'],
#  ['country',
#   'going',
#   'hell',
#   'megyn',
#   'kelly',
#   'foxnews',
#   'attacking',
#   'trump',
#   'war',
#   'women',
#   'gopdebate'],
#  ['franklin',
#   'graham',
#   '1st',
#   'gopdebate',
#   'encouraging',
#   'see',
#   'several',
#   'candidates',
#   'express',
#   'faith',
#   'god',
#   'son',
#   'jesus',
#   'christ',
#   'http',
#   'c'],
#  ['snarkydemo',
#   'donaldtrump',
#   'said',
#   'politically',
#   'correct',
#   'course',
#   'trumpspeak',
#   'let',
#   'face',
#   'huge',
#   'asshole'],
#  ['bipartisanism',
#   'message',
#   'gopdebate',
#   'candidates',
#   'http',
#   'co',
#   'wfk5cmvgin'],
#  ['davidcicilline',
#   'worst',
#   'episode',
#   'apprentice',
#   'ever',
#   'seen',
#   'gopdebate'],
#  ['govmikehuckabee',
#   'luntz',
#   'lines',
#   'go',
#   'almost',
#   'reach',
#   '100',
#   'almost',
#   'never',
#   'happens',
#   'dial',
#   'research',
#   'gopdebate',
#   'htt'],
#  ['lolhayley',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'something',
#   'actual',
#   'man',
#   'running',
#   'president',
#   'said'],
#  ['wondering',
#   'could',
#   'get',
#   'republican',
#   'party',
#   'pay',
#   'liver',
#   'transplant',
#   'playing',
#   'mtaibbi',
#   'gopdebate',
#   'drinking',
#   'game',
#   'last',
#   'night'],
#  ['brandondhowell',
#   'great',
#   'way',
#   'stafriday',
#   'carlyfiorina',
#   'carlyfiorina',
#   'gopdebate',
#   'http',
#   'co',
#   '1ai9cuz8by'],
#  ['tedcruz',
#   'elected',
#   'first',
#   'day',
#   'president',
#   'rescind',
#   'every',
#   'illegal',
#   'unconstitutional',
#   'executive',
#   'order',
#   'enacted',
#   'pres',
#   'oba'],
#  ['ronnie2k',
#   'donald',
#   'trump',
#   'gopdebate',
#   'like',
#   'https',
#   'co',
#   'jcuirk1i1u'],
#  ['bruneski',
#   'upstairs',
#   'putting',
#   'kids',
#   'bed',
#   'many',
#   'questions',
#   'climate',
#   'change',
#   'miss',
#   'gopdebate',
#   'gopclowncar'],
#  ['todd',
#   'akin',
#   'planned',
#   'parenthood',
#   'sting',
#   'backfired',
#   'republicans',
#   'gopdebate',
#   'standwithpp',
#   'http',
#   'co',
#   'ekxpfkthqn'],
#  ['learjetter',
#   'hey',
#   'foxnews',
#   'let',
#   'republicans',
#   'digest',
#   'gopdebate',
#   'allowing',
#   'crazy',
#   'dwstweets',
#   'trash',
#   'gop',
#   'ladysandersfarm',
#   'http'],
#  ['thebaxterbean',
#   'watch',
#   'donald',
#   'trump',
#   'receive',
#   'enormous',
#   'applause',
#   'horribly',
#   'misogynistic',
#   'gopdebate',
#   'answer',
#   'http',
#   'co',
#   'r4e8tpotd5',
#   'http'],
#  ['favorite',
#   'twitter',
#   'responses',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '2iqcdrcdlm',
#   'http',
#   'co',
#   '7tdma3vlm8'],
#  ['even',
#   'though',
#   'super',
#   'conservative',
#   'reporter',
#   'actually',
#   'like',
#   'megyn',
#   'kelly',
#   'interview',
#   'style',
#   'amp',
#   'great',
#   'gopdebate'],
#  ['kingsthings',
#   'gopdebate',
#   'debate',
#   'series',
#   '1',
#   'minute',
#   'opportunities',
#   'avoid',
#   'answering',
#   'question',
#   'one',
#   'candidate'],
#  ['melissagracey',
#   'credit',
#   'joke',
#   'goes',
#   'someone',
#   'else',
#   'funny',
#   'gopdebate',
#   'http',
#   'co',
#   'icredssplr'],
#  ['reince',
#   'simply',
#   'incredible',
#   'http',
#   'co',
#   'apxm8ao8jf',
#   'last',
#   'night',
#   'gopdebate',
#   'doubled',
#   'previous',
#   'record',
#   'watched',
#   'primary',
#   'debate'],
#  ['katethomas',
#   'literally',
#   'true',
#   'watched',
#   'gopdebate',
#   'amp',
#   'got',
#   'lousy',
#   'hangover',
#   'http',
#   'co',
#   'cxch7x'],
#  ['fl',
#   'dreamer',
#   'haha',
#   'little',
#   'saas',
#   'voxdotcom',
#   'morning',
#   'towards',
#   'realdonaldtrump',
#   'factchecked',
#   'gopdebate',
#   'http',
#   'co',
#   'daectmllaj'],
#  ['texascruzn',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   '1z3vufjzlw'],
#  ['zellieimani',
#   'people',
#   'saw',
#   'person',
#   'vs',
#   'saw',
#   'tv',
#   'gopdebate',
#   'http',
#   'co',
#   'qlgsxrh5hw'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'told',
#   'face',
#   'candidate',
#   'yesterday',
#   'anti',
#   'gay',
#   'bigotry',
#   'http',
#   'co',
#   'a4eiuettlf',
#   'gopdebate',
#   'ht'],
#  ['cariisie',
#   'none',
#   'made',
#   'trump',
#   'look',
#   'place',
#   'foolish',
#   'yet',
#   'think',
#   'done',
#   'crying',
#   'think',
#   'agai'],
#  ['akbarjenkins',
#   'maybe',
#   'gop',
#   'got',
#   'piven',
#   'amp',
#   'cloward',
#   'confused',
#   'pinkard',
#   'amp',
#   'bowden',
#   'thinks',
#   'steal',
#   'cars',
#   'kevinbaker',
#   'kevinmkr'],
#  ['great',
#   'time',
#   'watching',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   'qcmxmu8mlp'],
#  ['jrehling',
#   'gopdebate',
#   'donald',
#   'trump',
#   'says',
#   'time',
#   'political',
#   'correctness',
#   'calling',
#   'women',
#   'fat',
#   'pigs',
#   'save'],
#  ['theonlyadult',
#   'potus',
#   'one',
#   'people',
#   'tv',
#   'might',
#   'next',
#   'one',
#   'rip',
#   'everything',
#   'gopdebate',
#   'http',
#   'co'],
#  ['think',
#   'realdonaldtrump',
#   'caught',
#   'surprise',
#   'first',
#   'question',
#   'never',
#   'able',
#   'recover',
#   'equilibrium',
#   'gopdebate'],
#  ['kirahoffy',
#   'foxnews',
#   'web',
#   'stream',
#   'mobile',
#   'app',
#   'fail',
#   'gopdebate',
#   'surprised',
#   'http',
#   'co',
#   'tkpesooezt'],
#  ['johnkasich',
#   'john',
#   'kasich',
#   'helped',
#   'ohioans',
#   'create',
#   '350',
#   '000',
#   'new',
#   'jobs',
#   'america',
#   'gopdebate',
#   'http',
#   'co',
#   'kbzfbjyp2c'],
#  ['please',
#   'help',
#   'maryknoll',
#   'sisters',
#   'replace',
#   'windows',
#   'convent',
#   'https',
#   'co',
#   'fdgxg3vv13',
#   'catholic',
#   'gofundme',
#   'trcot',
#   'gopdebate'],
#  ['carlyfiorina',
#   'gopdebate',
#   'largest',
#   'audience',
#   'yet',
#   'chip',
#   '3',
#   'help',
#   'us',
#   'keep',
#   'https',
#   'co',
#   'nzync1jrxs',
#   'http'],
#  ['trump',
#   'said',
#   'jebbush',
#   'true',
#   'gentleman',
#   'amp',
#   'started',
#   'violently',
#   '69ing',
#   'gopdebate'],
#  ['cameronesposito',
#   'ugh',
#   'guys',
#   'ever',
#   'shut',
#   'much',
#   'respect',
#   'women',
#   'gopdebate'],
#  ['snarkydemo',
#   'gopdebate',
#   'teach',
#   'us',
#   'future',
#   'president',
#   'trump',
#   'america',
#   'probably',
#   'safe',
#   'except',
#   'attacked'],
#  ['congoboy',
#   'going',
#   'long',
#   'tiring',
#   'election',
#   'season',
#   'shockingly',
#   'ill',
#   'informed',
#   'candidates',
#   'gopdebate',
#   'http',
#   'co',
#   'vtk1k0txi'],
#  ['amymek',
#   'god',
#   'blessed',
#   'republican',
#   'party',
#   'many',
#   'great',
#   'candidates',
#   'thedemocrats',
#   'even',
#   'find',
#   'one',
#   'marcorubio',
#   'gopdebate'],
#  ['johnkasich',
#   'miracle',
#   'happen',
#   'grow',
#   'opportunity',
#   'grow',
#   'jobs',
#   'gopdebate',
#   'http',
#   'co',
#   'lnqhdgtudk'],
#  ['mattyiceaz', 'scott', 'walker', 'even', 'carry', 'state', 'gopdebate'],
#  ['xlnb',
#   'black',
#   'people',
#   'need',
#   'anymore',
#   'indication',
#   'republicans',
#   'hate',
#   'us',
#   'peep',
#   'gopdebate',
#   'http',
#   'co',
#   'bh0chsy5eh'],
#  ['smethanie',
#   'sure',
#   'god',
#   'told',
#   'run',
#   'tooth',
#   'fairy',
#   'agreed',
#   'teletubbies',
#   'voted',
#   'yes',
#   'gopdebate'],
#  ['palmaceiahome1',
#   'trump',
#   'told',
#   'megyn',
#   'kelly',
#   'go',
#   'hell',
#   'foxnews',
#   'gopdebate'],
#  ['palmaceiahome1',
#   'caller',
#   'rush',
#   'limbaugh',
#   'show',
#   'lost',
#   'respect',
#   'fox',
#   'news',
#   'foxnews',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'stinger',
#   'inc',
#   'realdonaldtrump',
#   'megynkelly',
#   'behaviour',
#   'gopdebate',
#   'astonishingly',
#   'biased'],
#  ['republicans',
#   'debate',
#   'economics',
#   'rubio',
#   'wins',
#   'bush',
#   'falters',
#   'huckabee',
#   'exaggerates',
#   'http',
#   'co',
#   'molloaqhwq',
#   'gopdebate',
#   'knowmorenotless',
#   'gpnaplang'],
#  ['jamesviser',
#   'huh',
#   'half',
#   'clinton',
#   'charity',
#   'went',
#   'clintons',
#   'http',
#   'co',
#   'bvwrosgwal',
#   'copolitics',
#   'hillary2016',
#   'stophillary',
#   'uniteb'],
#  ['kraig4u',
#   'gopdebate',
#   'order',
#   'take',
#   'trump',
#   'wonder',
#   'fox',
#   'news',
#   'one',
#   'took',
#   'order',
#   'seriously',
#   'heidil',
#   'rn'],
#  ['diegouk',
#   'democrats',
#   'watching',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '7v4wjok3vm',
#   'p2',
#   'ctl',
#   'topprog',
#   'tcot',
#   'tlot'],
#  ['amymek',
#   'owe',
#   'realdonaldtrump',
#   'huge',
#   'thank',
#   '4',
#   'exposing',
#   'world',
#   'megynkelly',
#   'chris',
#   'wallace',
#   'amp',
#   'frankluntz',
#   'true',
#   'rhinos'],
#  ['thebaxterbean',
#   'scott',
#   'walker',
#   'lies',
#   'says',
#   'wi',
#   'budget',
#   '535m',
#   'surplus',
#   'actually',
#   '1',
#   '76b',
#   'deficit',
#   'http',
#   'co',
#   'vvmxzkxlkr',
#   'gopdebate',
#   'http'],
#  ['right',
#   'last',
#   'heard',
#   'sensanders',
#   'women',
#   'could',
#   'give',
#   'birth',
#   'child',
#   'changed',
#   'gopdebate',
#   'https',
#   'co',
#   '5hkcefp1hf'],
#  ['pattonoswalt',
#   'received',
#   'word',
#   'god',
#   'soup',
#   'sandwich',
#   'crazy',
#   'gopdebate'],
#  ['frankconniff',
#   'fox',
#   'news',
#   'gopdebate',
#   'interviewer',
#   'candidates',
#   'take',
#   'gop',
#   'talking',
#   'points',
#   'feeding'],
#  ['lesliemac',
#   'murder',
#   'black',
#   'ppl',
#   'fine',
#   'unborn',
#   'black',
#   'babies',
#   'goplogic',
#   'gopdebate'],
#  ['hillaryclinton',
#   'missing',
#   'jon',
#   'stewaalready',
#   'gopdebate',
#   'jonvoyage',
#   'h'],
#  ['charlottelaws', 'chris', 'christie', 'really', 'standing', 'gopdebate'],
#  ['libertyjibbet',
#   'hey',
#   'realdonaldtrump',
#   'know',
#   'whine',
#   'unfair',
#   'questions',
#   'carlyfiorina',
#   'grow',
#   'set',
#   'ya',
#   'gopde'],
#  ['pro',
#   'life',
#   'watched',
#   '2',
#   'hour',
#   'abortion',
#   'last',
#   'night',
#   'gopdebate',
#   'forkedtongue',
#   'iseeorangepeople'],
#  ['danscavino',
#   'megynkelly',
#   'failed',
#   'american',
#   'people',
#   'tonight',
#   'tried',
#   'make',
#   'history',
#   'destroying',
#   'realdonaldtrump',
#   'kellyfai'],
#  ['edstetzer',
#   'btw',
#   'mix',
#   'politics',
#   'religion',
#   'get',
#   'politics',
#   'gopdebate'],
#  ['teammarco',
#   'marco',
#   'nailed',
#   'abortion',
#   'must',
#   'protect',
#   'life',
#   'gopdebate',
#   'http',
#   'co',
#   'nn6s7do22j'],
#  ['megynkelly',
#   'bretbaier',
#   'foxnews',
#   'wtf',
#   'chris',
#   'wallace',
#   'attacking',
#   'trump2016',
#   'bankruptcy',
#   'giving',
#   'rubio',
#   'softball',
#   'gopdebate'],
#  ['obviously',
#   'get',
#   'memo',
#   'seersuckerthursday',
#   'gopdebate',
#   'http',
#   'co',
#   'lzagrrtzfl'],
#  ['vh1',
#   'honestly',
#   'donald',
#   'trump',
#   'types',
#   'petty',
#   'last',
#   'night',
#   'gopdebate',
#   'gt',
#   'http',
#   'co',
#   'qxdoemfuqo',
#   'http',
#   'co',
#   'mcr6lrjh2h'],
#  ['tuxcedocat',
#   'republican',
#   'dopefuls',
#   'say',
#   'take',
#   'us',
#   'back',
#   '2009',
#   'day',
#   'one',
#   'never',
#   'see',
#   'one',
#   'day',
#   'white',
#   'house',
#   'gopdebate'],
#  ['trump',
#   'gloating',
#   'abt',
#   'buying',
#   'gop',
#   'dem',
#   'pols',
#   'amp',
#   'bidding',
#   '2000s',
#   'billionaire',
#   'caricature',
#   'myacash',
#   'gopdebate',
#   'https',
#   'co',
#   '5spmu3csic'],
#  ['peddoc63',
#   'go',
#   'carly',
#   'go',
#   'carly',
#   'go',
#   'carly',
#   'carlyfiorina',
#   'carly2016',
#   'gopdebate',
#   'flyoverculture',
#   'leahr77',
#   'steph93065',
#   'maydnusa',
#   'http',
#   'co'],
#  ['daenerys', 'listening', 'gopdebate', 'like', 'http', 'co', '3jrcuqdafu'],
#  ['scorpionspriest',
#   'best',
#   'moment',
#   'gopdebate',
#   'last',
#   'night',
#   'rand',
#   'telling',
#   'christie',
#   'go',
#   'get',
#   'another',
#   'hug',
#   'obama'],
#  ['johnfugelsang',
#   'missed',
#   'either',
#   'gopdebate',
#   'need',
#   'know',
#   'struggling',
#   'americans',
#   'unlimited',
#   'war'],
#  ['pfikac',
#   'jebbush',
#   'verge',
#   'greatest',
#   'time',
#   'alive',
#   'world',
#   'washington',
#   'holding',
#   'us',
#   'back',
#   'mysa',
#   'txlege'],
#  ['drmartyfox',
#   'trump',
#   'wins',
#   'drudge',
#   'debate',
#   'poll',
#   'landslide',
#   'tedcruz',
#   '2',
#   'gopdebate',
#   'pjnet',
#   'http',
#   'co',
#   'yuh6j7qqha',
#   'http'],
#  ['siteroi',
#   'governorperry',
#   'fights',
#   'back',
#   'abt',
#   'immigration',
#   'q',
#   'says',
#   'border',
#   'porous',
#   'must',
#   'fixed',
#   'first'],
#  ['summary', 'gopdebate', 'status', 'quo', 'shit', 'show'],
#  ['thepatriot143',
#   'debbie',
#   'blocks',
#   'tweeter',
#   'questioned',
#   'dem',
#   'debate',
#   'schedule',
#   'http',
#   'co',
#   'gxna0toqaq',
#   'gopdebate',
#   'dwstweets',
#   'http',
#   'co',
#   'kxikf'],
#  ['sallykohn',
#   'hey',
#   'look',
#   '10',
#   'men',
#   'standing',
#   'stage',
#   'arguing',
#   'get',
#   'control',
#   'women',
#   'bodies',
#   'choices',
#   'gopdebate'],
#  ['thebaxterbean',
#   'rubio',
#   'budget',
#   'raises',
#   'middleclass',
#   'taxes',
#   'adds',
#   '4',
#   '5t',
#   'deficit',
#   'cuts',
#   'investmenttax',
#   '0',
#   'http',
#   'co',
#   '9s9nuvsaf7',
#   'gopdebate',
#   'ht'],
#  ['chrisjzullo',
#   'last',
#   'night',
#   'gopdebate',
#   'saw',
#   'bunch',
#   'rich',
#   'old',
#   'despots',
#   'zero',
#   'solutions',
#   'nations',
#   'problems',
#   'un'],
#  ['nancyosborne180',
#   'gopdebate',
#   'batsask',
#   'badassteachersa',
#   'tbats',
#   'debate',
#   'learned',
#   'nothing',
#   'new',
#   'http',
#   'co',
#   'vmtnri7xev',
#   'http',
#   'co',
#   '6mt'],
#  ['rfhkerry', 'think', 'people', 'qualified', 'unfollow', 'gopdebate'],
#  ['bipartisanism',
#   'ben',
#   'carson',
#   'spoke',
#   'science',
#   'gopdebate',
#   'neiltyson',
#   'like',
#   'http',
#   'co',
#   'byooh7i3n6'],
#  ['real',
#   'illegal',
#   'alien',
#   'gopdebate',
#   'farrakhan',
#   'immigration',
#   'mexican',
#   'bor',
#   'https',
#   'co',
#   'lklffn2lfy',
#   'via',
#   'youtube'],
#  ['gopdebate',
#   'talking',
#   'heads',
#   'put',
#   'debate',
#   'talking',
#   'heads',
#   'telling',
#   'us',
#   'debates',
#   'went',
#   'maybe',
#   'wasted',
#   'time',
#   'watching'],
#  ['steel5757',
#   'donaldtrump',
#   'plaza',
#   'casino',
#   'teddybear',
#   'plush',
#   'tuxedo',
#   'http',
#   'co',
#   'qhttx0pldg',
#   'coolstuff',
#   'gopdebate',
#   'http',
#   'co',
#   'qjunzjy'],
#  ['trump',
#   'right',
#   'megynkelly',
#   'really',
#   'needs',
#   'study',
#   'matthew',
#   '7',
#   'verses',
#   '3',
#   '5',
#   'gopdebate',
#   'https',
#   'co',
#   'ygnprhiehv'],
#  ['ac360',
#   'donaldtrump',
#   'memorable',
#   'gopdebate',
#   'moments',
#   'right',
#   'ac360',
#   'http',
#   'co',
#   'kdnhgj2ry3',
#   'http',
#   'co',
#   'hz9gwe'],
#  ['gopdebate', 'one', 'picture', 'http', 'co', 'wmmucjuqju'],
#  ['maureenjohnson',
#   'think',
#   'women',
#   'sleep',
#   'curse',
#   'shed',
#   'open',
#   'field',
#   'property'],
#  ['think',
#   'god',
#   'pretty',
#   'fair',
#   'guy',
#   'ben',
#   'carson',
#   'neurosurgeon',
#   'belief',
#   'modern',
#   'day',
#   'taxation',
#   'based',
#   'ancient',
#   'book',
#   'gopdebate'],
#  ['nancyleegrahn',
#   'cheers',
#   'gopdebate',
#   'audience',
#   'aftertrump',
#   'defiantly',
#   'named',
#   'rosie',
#   'woman',
#   'called',
#   'fat',
#   'pig',
#   'voices'],
#  ['blacklives',
#   'matter',
#   'apparently',
#   'republican',
#   'candidates',
#   'president',
#   'http',
#   'co',
#   '8rfevfwsxx',
#   'foxnews',
#   'uniteblue',
#   'gopdebate'],
#  ['overall',
#   'main',
#   'thing',
#   'learned',
#   'gopdebate',
#   'straight',
#   'white',
#   'men',
#   'matter'],
#  ['usfree4life',
#   'thought',
#   'seanhannity',
#   'best',
#   'post',
#   'gopdebate',
#   'interviews',
#   'night',
#   'gave',
#   'chance',
#   '2straighten',
#   'position'],
#  ['johnkasich',
#   'hey',
#   'realdonaldtrump',
#   'still',
#   'looking',
#   'chip',
#   'check',
#   'http',
#   'co',
#   'dy8knz122t',
#   'gopdebate'],
#  ['megynkelly',
#   'bretbaier',
#   'chriswallace',
#   'america',
#   'criticizing',
#   'ur',
#   'performances',
#   'gopdebate',
#   'b',
#   'c',
#   'u',
#   'really',
#   'bad',
#   'job',
#   'moderators'],
#  ['govmikehuckabee',
#   'luntz',
#   'lines',
#   'go',
#   'almost',
#   'reach',
#   '100',
#   'almost',
#   'never',
#   'happens',
#   'dial',
#   'research',
#   'gopdebate',
#   'rigged'],
#  ['oftenimprudent',
#   'wish',
#   'could',
#   'teach',
#   'teenage',
#   'girls',
#   'love',
#   'much',
#   'donald',
#   'trump',
#   'loves',
#   'gopdebate'],
#  ['amymek',
#   'conservatives',
#   'people',
#   'without',
#   'network',
#   'gopdebate',
#   'foxnews'],
#  ['bhowl',
#   'come',
#   'talk',
#   'climate',
#   'change',
#   'anyone',
#   'even',
#   'seen',
#   'california',
#   'right',
#   'gopdebate',
#   'debatewithbernie'],
#  ['travisconsidine',
#   'governorperry',
#   'gopdebate',
#   'performance',
#   'review',
#   'reel',
#   'https',
#   'co',
#   'o5qurozbku',
#   'perry2016'],
#  ['chrisjzullo',
#   'last',
#   'night',
#   'could',
#   'raised',
#   'hands',
#   'spoiled',
#   'billionaire',
#   'oligarch',
#   'racist',
#   'religi'],
#  ['gopdebate',
#   '2016',
#   'teamdrbencarson',
#   'realbencarson',
#   'wow',
#   'brilliant',
#   'cool',
#   'calm',
#   'amp',
#   'collected',
#   'empowering'],
#  ['soopermexican',
#   'ted',
#   'cruz',
#   'appreciate',
#   'emphatically',
#   'sarcastic',
#   'air',
#   'quotes',
#   'megan',
#   'kelly',
#   'gopdebate'],
#  ['benjamminwalker',
#   'circumstances',
#   '10',
#   'men',
#   'dictate',
#   'abortion',
#   'rights',
#   'women',
#   '21st',
#   'century',
#   'better'],
#  ['danscavino',
#   'gopdebate',
#   'winner',
#   'drudge',
#   '50',
#   '187k',
#   'realdonaldtrump',
#   'time',
#   '46',
#   '25k',
#   'realdonaldtrump',
#   'foxsd',
#   '49',
#   'realdonaldtrump',
#   'http'],
#  ['joeprich',
#   'megynkelly',
#   '2012',
#   'chided',
#   'candycrowley',
#   'going',
#   'objective',
#   'moderator',
#   'active',
#   'participant',
#   'gopdebate',
#   'http'],
#  ['gopdebate',
#   'foxnews',
#   'realdonaldtrump',
#   'in1996',
#   'called',
#   'billclinton',
#   'two',
#   'timing',
#   'slut',
#   'stand',
#   'statement'],
#  ['renomarky',
#   'never',
#   'watch',
#   'kellyfile',
#   '1',
#   'gopdebate',
#   'questions',
#   '2',
#   'pandering',
#   'dwstweets',
#   '3',
#   'making',
#   'ratings',
#   'http'],
#  ['imho',
#   'gopdebate',
#   'winners',
#   'marcorubio',
#   'kasich',
#   'donaldtrump',
#   'losers',
#   'scottwalker',
#   'randpaul',
#   'bencarson',
#   'others',
#   'completely',
#   'forgettable'],
#  ['johnkasich',
#   'smaller',
#   'govt',
#   'ohio',
#   'government',
#   'payroll',
#   'smaller',
#   '3',
#   'decades',
#   'http',
#   'co',
#   'igfif4j1tt',
#   'gopdebate',
#   'http',
#   'co'],
#  ['zellieimani',
#   'twitter',
#   'users',
#   'takeover',
#   'gopdebate',
#   'hashtag',
#   'drag',
#   'gop',
#   'candidates',
#   'https',
#   'co',
#   'lmznompfmw',
#   'kkkorgop',
#   'http',
#   'co',
#   'ewez899a0c'],
#  ['jebbush',
#   'challenging',
#   'teacher',
#   'unions',
#   'beating',
#   'way',
#   'go',
#   'jeb',
#   'http',
#   'co',
#   '5imgwdrl4g',
#   'gopdebate'],
#  ['billyeichner',
#   'thank',
#   'watching',
#   'gopdebate',
#   'tonight',
#   'julieklausner',
#   'blast',
#   'writing'],
#  ['theblaze',
#   'real',
#   'war',
#   'women',
#   'realdonaldtrump',
#   'megynkelly',
#   'rushlimbaugh',
#   'gopdebate',
#   'anncoulter'],
#  ['governorperry',
#   'governorperry',
#   'fire',
#   'debate',
#   'performance',
#   'https',
#   'co',
#   'armjn6vwpg',
#   'gopdebate',
#   'perry2016',
#   'tcot'],
#  ['blowticious',
#   'pro',
#   'life',
#   'republicans',
#   'like',
#   'gopdebate',
#   'http',
#   'co',
#   'bioxoplejn'],
#  ['governorperry',
#   'icymi',
#   'governorperry',
#   'border',
#   'security',
#   'illegal',
#   'immigration',
#   'gopdebate',
#   'perry2016',
#   'tcot',
#   'https',
#   'co',
#   '1s25d2d0nk'],
#  ['allthingsflynn',
#   'trump',
#   'vs',
#   'fox',
#   'news',
#   'conflict',
#   'quite',
#   'conundrum',
#   'like',
#   'personification',
#   'greed',
#   'vs',
#   'hate',
#   'root'],
#  ['carlyfiorina', 'know', 'extraordinary', 'nation', 'gopdebate'],
#  ['laxnoreos',
#   'meanwhile',
#   'white',
#   'house',
#   'gopdebate',
#   'http',
#   'co',
#   'mfs7ixfovc'],
#  ['rubio',
#   'still',
#   'preference',
#   'see',
#   'point',
#   'critics',
#   'opportunism',
#   'inconsistency',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'ever',
#   'tell',
#   'megynkelly',
#   'go',
#   'wait',
#   'car',
#   'bad',
#   'attitude',
#   'suggests',
#   'waronwomen',
#   'gopdebate'],
#  ['thetexasphoenix',
#   'fire',
#   'governorperry',
#   'fire',
#   'debate',
#   'performance',
#   'https',
#   'co',
#   '0a1w02w7sz',
#   'gopdebate',
#   'perry2016'],
#  ['playing', 'dad', 'settling', 'gopdebate', 'http', 'co', 'w6w3e5nboa'],
#  ['realdonaldtrump',
#   'frankluntz',
#   'getting',
#   'lot',
#   'megynkelly',
#   'hatemail',
#   'tonight',
#   'gopdebate',
#   'totally',
#   'overrated',
#   'angry'],
#  ['literally',
#   'true',
#   'watched',
#   'gopdebate',
#   'amp',
#   'got',
#   'lousy',
#   'hangover',
#   'http',
#   'co',
#   'cxch7xxq1v',
#   'robinmarty'],
#  ['jonvoyage', 'half', 'long', 'gopdebate', 'twice', 'intelligible'],
#  ['lisabloom',
#   'single',
#   'question',
#   'last',
#   'night',
#   'gopdebate',
#   'urgent',
#   'issue',
#   'time',
#   'climate',
#   'change'],
#  ['gopdebate',
#   'foxnews',
#   'amp',
#   'gotcha',
#   'questions',
#   'seemed',
#   'designed',
#   'elicit',
#   'typical',
#   'political',
#   'spin',
#   'responses',
#   'tlot'],
#  ['gopdebate',
#   'promises',
#   'made',
#   'startups',
#   'tech',
#   'conference',
#   'seem',
#   'quite',
#   'reasonable'],
#  ['roy',
#   'rogers',
#   'knuckldraginsam',
#   'gop',
#   'realdonaldtrump',
#   'yobynnad1127',
#   'amen',
#   'trump2016',
#   'wakeupamerica',
#   'gopdebate',
#   'tcot',
#   'stoprush',
#   'http'],
#  ['carlyfiorina',
#   'highest',
#   'calling',
#   'leadership',
#   'challenge',
#   'status',
#   'quo',
#   'amp',
#   'unlock',
#   'potential',
#   'others',
#   'gopdebate',
#   'carly2016'],
#  ['zzcrane',
#   'watching',
#   'donald',
#   'trump',
#   'bandwagon',
#   'pass',
#   'tlot',
#   'tcot',
#   'gopdebate',
#   'http',
#   'co',
#   'wvqlsxgmcl'],
#  ['deray',
#   'gopdebate',
#   'began',
#   'moderators',
#   'say',
#   '8',
#   'million',
#   'ppl',
#   'discussing',
#   'racial',
#   'issues',
#   'happened',
#   'thos'],
#  ['feministabulous',
#   'nothing',
#   'like',
#   'listening',
#   'ten',
#   'dudes',
#   'never',
#   'need',
#   'abortion',
#   'talk',
#   'whether',
#   'right'],
#  ['senwhitehouse',
#   'fox',
#   'silenced',
#   'koch',
#   'billions',
#   'single',
#   'question',
#   'last',
#   'night',
#   'gopdebate',
#   'climatechange',
#   'deniers',
#   'mond'],
#  ['tyriquex',
#   'republicans',
#   'rich',
#   'care',
#   'poverty',
#   'america',
#   'amp',
#   'definitely',
#   'care',
#   'bout',
#   'poverty',
#   'bla'],
#  ['office',
#   'chat',
#   'gopdebate',
#   'amp',
#   'outed',
#   'flaming',
#   'liberal',
#   'politics',
#   'geek',
#   'probably',
#   'surprising'],
#  ['catching',
#   'gopdebate',
#   'lindseygrahamsc',
#   'childish',
#   'amp',
#   'cheap',
#   'move',
#   'call',
#   'billclinton',
#   'amp',
#   'hillaryclinton',
#   '17',
#   'year',
#   'old',
#   'story'],
#  ['tomhall',
#   'thing',
#   'could',
#   'made',
#   'last',
#   'night',
#   'gopdebate',
#   'amusing',
#   'would',
#   'cowbells',
#   'morecowbells',
#   'http',
#   'co'],
#  ['kesgardner', 'ted', 'cruz', 'attack', 'republicans', 'gopdebate'],
#  ['governorperry',
#   'icymi',
#   'hell',
#   'irandeal',
#   'gopdebate',
#   'perry2016',
#   'tcot',
#   'https',
#   'co',
#   'kqhjdjcgws'],
#  ['frankconniff', 'hard', 'say', 'gopdebate', 'bernie', 'hillary'],
#  ['larhunter',
#   'donald',
#   'trump',
#   'wins',
#   'election',
#   'know',
#   'biff',
#   'stole',
#   'almanac',
#   'timeline',
#   'gopdebate'],
#  ['carlyfiorina',
#   'chip',
#   '3',
#   'keep',
#   'momentum',
#   'going',
#   'gopdebate',
#   'carly2016',
#   'https',
#   'co',
#   'w3mtcmr7ze'],
#  ['cenkuygur',
#   'chris',
#   'christie',
#   'said',
#   'work',
#   'two',
#   'years',
#   'retiring',
#   'get',
#   'tens',
#   'thousands',
#   'less',
#   'paid'],
#  ['johnkasich',
#   'john',
#   'kasich',
#   'ready',
#   'lead',
#   'join',
#   'team',
#   'claire',
#   'http',
#   'co',
#   'dy8knz122t',
#   'gopdebate',
#   'https',
#   'co',
#   'knwmideqty'],
#  ['edwrather',
#   'biggest',
#   'losers',
#   'debate',
#   'fox',
#   'moderators',
#   'attacked',
#   'instead',
#   'moderating',
#   'gopdebate'],
#  ['whitneyneal',
#   'trump',
#   'yet',
#   'give',
#   'single',
#   'evidence',
#   'based',
#   'answer',
#   'direct',
#   'question',
#   'policy',
#   'frighten',
#   'gopdeb'],
#  ['way',
#   'studio',
#   'appear',
#   'cnn',
#   'discuss',
#   'last',
#   'night',
#   'gopdebate',
#   'tune'],
#  ['blkfeminst',
#   'honestly',
#   'think',
#   'sometimes',
#   'guys',
#   'forgot',
#   'came',
#   'wombs',
#   'kkkorgop',
#   'gopdebate',
#   'https',
#   'co',
#   'fo3a6dxflf'],
#  ['grneyedmandy',
#   'women',
#   'shame',
#   'women',
#   'abortions',
#   'deserve',
#   'shamed',
#   'soul',
#   'self',
#   'respect',
#   'plannedparen'],
#  ['amandajogomez',
#   'watches',
#   'gopdebate',
#   'looks',
#   'directly',
#   'camera',
#   'like',
#   'office'],
#  ['icaruspundit',
#   'donald',
#   'trump',
#   'closing',
#   'statement',
#   'every',
#   'dinner',
#   'conversation',
#   'villages',
#   'ever',
#   'gopdebate'],
#  ['thexclass',
#   'rich',
#   'wage',
#   'war',
#   'poor',
#   'die',
#   'jean',
#   'paul',
#   'sartre',
#   'gop',
#   'foreign',
#   'policy',
#   'gopdebate'],
#  ['gopdebate',
#   'saw',
#   'candidates',
#   'completely',
#   'miss',
#   'mark',
#   'race',
#   'amp',
#   'blacklivesmatter',
#   'http',
#   'co',
#   'k9nhdpue32',
#   'http',
#   'co',
#   'hlcqpxjzru'],
#  ['seabassthephish',
#   'gop',
#   'proud',
#   'defeating',
#   'teachers',
#   'union',
#   'even',
#   'though',
#   'wanted',
#   'higher',
#   'wages',
#   'gopdebate'],
#  ['writeintrump',
#   'obama',
#   'better',
#   'leave',
#   'prayer',
#   'rug',
#   'behind',
#   'oval',
#   'office',
#   'get',
#   'elected',
#   'throw',
#   'gopdebate'],
#  ['chucknellis', 'foxnews', 'got', 'right', 'gopdebate'],
#  ['mrskimcam',
#   'trump',
#   'said',
#   'u',
#   'stupid',
#   'let',
#   'vote',
#   'president',
#   'wtf',
#   'people',
#   'gopdebate'],
#  ['excited',
#   'johnkasich',
#   'gopdebate',
#   'kasich4us',
#   'republicandebate',
#   'kasich2016',
#   'waiting',
#   '20',
#   'years'],
#  ['chadpergram',
#   'rep',
#   'engel',
#   '2nd',
#   'major',
#   'jewish',
#   'democrat',
#   'announce',
#   'opposition',
#   'iran',
#   'deal',
#   'gopdebate',
#   'following',
#   'schumer',
#   'opposition'],
#  ['hey',
#   'look',
#   'feelings',
#   'donald',
#   'trump',
#   'summed',
#   'one',
#   'gif',
#   'gopdebate',
#   'http',
#   'co',
#   'zjwugwj9hz'],
#  ['tommychong', 'dudes', 'legalization', 'marijuana', 'gopdebate'],
#  ['cberesniova',
#   'learned',
#   'gopdebate',
#   'guy',
#   'dad',
#   'mailman',
#   'jesus',
#   'christ',
#   'everyone',
#   'running',
#   'mate',
#   'gop',
#   'run'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'briefly',
#   'backed',
#   'immigration',
#   'reform',
#   'privately',
#   'berated',
#   'dreamers',
#   'http',
#   'co',
#   'we77qdt3kt',
#   'gopdebate',
#   'http'],
#  ['damienfahey',
#   'french',
#   'kissed',
#   'jesus',
#   'christ',
#   'every',
#   'candidate',
#   'gopdebate'],
#  ['gopdebate',
#   'closingstatements',
#   'govmikehuckabee',
#   'honest',
#   'u',
#   'defs',
#   'talking',
#   'realdonaldtrump',
#   'coz',
#   'stealing',
#   'ur',
#   'schtick'],
#  ['cnn',
#   'msnbc',
#   'new',
#   'york',
#   'times',
#   'praise',
#   'fox',
#   'moderators',
#   'know',
#   'moderators',
#   'fucked',
#   'gopdebate'],
#  ['kesgardner', 'trump', 'lunatic', 'gopdebate'],
#  ['cruz', 'class', 'amp', 'truth', 'gets', 'vote', 'gopdebate'],
#  ['kesgardner',
#   'assclown',
#   'reason',
#   'anyone',
#   'even',
#   'talking',
#   'illegal',
#   'immigration',
#   'keep',
#   'digging',
#   'donald',
#   'gopdebate'],
#  ['berniesanders',
#   'tom',
#   'hanks',
#   'finally',
#   'somebody',
#   'makes',
#   'sense',
#   'gopdebate',
#   'debatewithbernie'],
#  ['southernhomo', 'olivia', 'pope', 'would', 'vote', 'guys', 'gopdebate'],
#  ['gop',
#   'candidates',
#   'want',
#   'reduce',
#   'taxes',
#   'huckabee',
#   'wants',
#   'legalize',
#   'prostitution',
#   'drugs',
#   'tax',
#   'gopdebate'],
#  ['kesgardner',
#   'hi',
#   'fox',
#   'panel',
#   'ask',
#   'donald',
#   'every',
#   'single',
#   'question',
#   'hand',
#   'shovel',
#   'keep',
#   'digging'],
#  ['josephkapsch',
#   'hillaryclinton',
#   'barackobama',
#   'joebiden',
#   'gopdebate',
#   'https',
#   'co',
#   'yi4qns3hzh'],
#  ['gopdebate',
#   'trump',
#   'breaking',
#   'records',
#   'polished',
#   'politician',
#   'makes',
#   'love',
#   'even',
#   'https',
#   'co',
#   'tgowchxf3x'],
#  ['berniesanders', 'oh', 'movie', 'trailer', 'gopdebate', 'debatewithbernie'],
#  ['tacticaldissent',
#   'sally',
#   'kohn',
#   'amp',
#   'debbie',
#   'wasserman',
#   'schultz',
#   'praising',
#   'megyn',
#   'kelly',
#   'tonight',
#   'tell',
#   'everything',
#   'need'],
#  ['trump',
#   'accessory',
#   'women',
#   'wearing',
#   'shoes',
#   'gopdebate',
#   'http',
#   'co',
#   'xz4zc1lt8n'],
#  ['funniest',
#   'line',
#   'coming',
#   'fr',
#   'republican',
#   'people',
#   'frustrated',
#   'fed',
#   'think',
#   'government',
#   'working',
#   'gopdebate'],
#  ['donald', 'trump', 'absolute', 'nut', 'entertaining', 'lol', 'gopdebate'],
#  ['thehill',
#   'top',
#   'gop',
#   'pundits',
#   'pick',
#   'gopdebate',
#   'winners',
#   'http',
#   'co',
#   'qpvju6p7sz',
#   'http',
#   'co',
#   'jcdu5qzjnj',
#   'winners',
#   'fox',
#   'news',
#   'losers',
#   'usa'],
#  ['dykstradame',
#   'candidates',
#   'went',
#   'hillaryclinton',
#   '32',
#   'times',
#   'gopdebate',
#   'remained',
#   'silent',
#   'issues',
#   'affect',
#   'us',
#   'http'],
#  ['danscavino',
#   'megynkelly',
#   'trying',
#   '2show',
#   'realdonaldtrump',
#   'w',
#   'foxnews',
#   'trying',
#   '2take',
#   'trying',
#   '2destroy',
#   'happening',
#   'kelly'],
#  ['gov',
#   'tweeted',
#   'gopdebate',
#   'moment',
#   'realbencarson',
#   'saying',
#   'publicize',
#   'world',
#   'answer',
#   'waterboarding'],
#  ['give',
#   'e',
#   'big',
#   'ego',
#   'gopdebate',
#   'earned',
#   'excellence',
#   'rhymes',
#   'rump'],
#  ['passion', 'gopdebate', 'religiousupamovie'],
#  ['nro',
#   'marcorubio',
#   'got',
#   'best',
#   'reviews',
#   'deserved',
#   'read',
#   'nreditorial',
#   'recap',
#   'gopdebate',
#   'gt',
#   'http',
#   'co',
#   'stzw'],
#  ['ohnoshetwitnt',
#   'wait',
#   'see',
#   'lannister',
#   'kill',
#   'next',
#   'episode',
#   'gopdebate'],
#  ['kesgardner',
#   'brutal',
#   'question',
#   'assclown',
#   'megan',
#   'kelly',
#   'lesson',
#   'careful',
#   'tweet',
#   'twitter',
#   'gopdebate'],
#  ['tusk81', 'democrats', 'watching', 'gopdebate', 'http', 'co', 'szicslm7km'],
#  ['trump',
#   'changed',
#   'mind',
#   'supporting',
#   'partial',
#   'birth',
#   'abortion',
#   'friend',
#   'changed',
#   'mind',
#   'aborting',
#   'amp',
#   'great',
#   'kid',
#   'gopdebate'],
#  ['best', 'closing', 'statement', 'realbencarson', 'gopdebate'],
#  ['chrischristie',
#   'stop',
#   'worrying',
#   'loved',
#   'amp',
#   'staworrying',
#   'respected',
#   'tellingitlikeitis',
#   'gopdebate',
#   'https'],
#  ['lesleyabravanel',
#   'trump',
#   'sycophants',
#   'want',
#   'know',
#   'megynkelly',
#   'hidden',
#   'agenda',
#   'last',
#   'night',
#   'answer',
#   'simple',
#   'called',
#   'vagin'],
#  ['real',
#   'gopdebate',
#   'winner',
#   'republican',
#   'voters',
#   'fox',
#   'nation',
#   'http',
#   'co',
#   '98g42iaz5o'],
#  ['donald',
#   'trump',
#   'really',
#   'nasty',
#   'piece',
#   'work',
#   'hope',
#   'disappears',
#   'quickly',
#   'gopdebate'],
#  ['amaraconda',
#   'fetuses',
#   'unborn',
#   'babies',
#   'clusters',
#   'cells',
#   'stop',
#   'shaming',
#   'people',
#   'want',
#   'abortions',
#   'gopdebate'],
#  ['mattkbh',
#   'far',
#   'away',
#   'best',
#   'tweets',
#   'last',
#   'night',
#   'debatewithbernie',
#   'gopdebate',
#   'http',
#   'co',
#   'gzdltyumnn'],
#  ['know',
#   'chrischristie',
#   'reminds',
#   'actor',
#   'andy',
#   'devine',
#   'gopdebate',
#   'http',
#   'co',
#   'xyy8fxpjcd'],
#  ['pattonoswalt',
#   'despite',
#   'huckabee',
#   'says',
#   'always',
#   'make',
#   'sure',
#   'prostitute',
#   'pimp',
#   'pay',
#   'fica',
#   'pension',
#   'gopdebate'],
#  ['bipartisanism',
#   'hillary',
#   'clinton',
#   'watching',
#   'gopdebate',
#   'like',
#   'http',
#   'co',
#   'vokolq52xp'],
#  ['foxnews',
#   'great',
#   'challenging',
#   'candidates',
#   'gopdebate',
#   'candidates',
#   'handle',
#   'tough',
#   'question',
#   'could',
#   'never',
#   'b',
#   'potus'],
#  ['k',
#   'mcq',
#   'say',
#   'opposite',
#   'megan',
#   'kelly',
#   'acted',
#   'like',
#   'sjw',
#   'tumblr',
#   'whining',
#   'feminism',
#   'sad',
#   'gopdebate',
#   'https',
#   'c'],
#  ['conssista',
#   'rightly',
#   'frank',
#   'rightly',
#   'gopdebate',
#   'https',
#   'co',
#   '32cfasi17d'],
#  ['number',
#   'times',
#   'ronald',
#   'reagan',
#   'mentioned',
#   'gopdebate',
#   'damn',
#   'high'],
#  ['pattonoswalt',
#   'trump',
#   'p',
#   'c',
#   'culture',
#   'suddenly',
#   '100',
#   'even',
#   'kidding',
#   'howling',
#   'shit',
#   'cave',
#   'human',
#   'gop'],
#  ['carljacksonshow',
#   'bencarson',
#   'great',
#   'close',
#   'operates',
#   'brains',
#   'worry',
#   'skin',
#   'color',
#   'gopdebate'],
#  ['davante',
#   'r',
#   'women',
#   'would',
#   'offended',
#   'trumps',
#   'misogyny',
#   'certainly',
#   'vote',
#   'republican',
#   'find',
#   'new',
#   'fake',
#   'issue',
#   'faux',
#   'news'],
#  ['auntcol54', 'keep', 'religion', 'politics', 'gopdebate'],
#  ['dianneg',
#   'bought',
#   'amp',
#   'sold',
#   'randpaul',
#   'reiterating',
#   'points',
#   'realdonaldtrump',
#   'gopdebate'],
#  ['wilw',
#   'boy',
#   'bet',
#   'mood',
#   'clown',
#   'car',
#   'going',
#   'tense',
#   'jerks',
#   'leave',
#   'gopdebate'],
#  ['campeauelliot',
#   'dr',
#   'ben',
#   'carson',
#   'great',
#   'job',
#   'tonight',
#   'loved',
#   'closing',
#   'statement',
#   'realbencarson',
#   'gopdebate'],
#  ['redheadandright',
#   'meet',
#   'new',
#   'darling',
#   'left',
#   'megyn',
#   'gotcha',
#   'kelly',
#   'gopdebate',
#   'foxnews',
#   'donaldtrump',
#   'megynkelly'],
#  ['foxnewspolitics',
#   'behind',
#   'fox',
#   'debate',
#   'anchors',
#   'hashed',
#   'questions',
#   'gopdebate',
#   'failed'],
#  ['anyone',
#   'get',
#   'trashed',
#   'playing',
#   'rollingstone',
#   'gopdebate',
#   'drinking',
#   'game',
#   'drinkinggame'],
#  ['donaldtrump',
#   'donates',
#   'u',
#   'call',
#   'favor',
#   'years',
#   'later',
#   'sounds',
#   'like',
#   'thegodfather',
#   'potus',
#   'thats',
#   'legal',
#   'gopdebate',
#   'gopclowncar'],
#  ['jediane9',
#   'ugh',
#   'think',
#   'actually',
#   'people',
#   'sitting',
#   'couch',
#   'last',
#   'night',
#   'saying',
#   'yes',
#   'yes',
#   'reasonable',
#   'gopdebate'],
#  ['barracudamama',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'e1smu0hn5j'],
#  ['kesgardner',
#   'politics',
#   'even',
#   'partially',
#   'rational',
#   'trump',
#   'campaign',
#   'gop',
#   'nomination',
#   'ended',
#   'gopdebate'],
#  ['andrewhclark',
#   'gaypatriot',
#   'takeaway',
#   'last',
#   'night',
#   'america',
#   'deserve',
#   'ben',
#   'carson',
#   'http',
#   'co',
#   'kjgfyypcte',
#   'gopdebate'],
#  ['chrisjzullo',
#   'scott',
#   'walker',
#   'chooses',
#   'killing',
#   'mother',
#   'rather',
#   'aborting',
#   'unborn',
#   'embryo',
#   'reason',
#   'countries',
#   'give',
#   'us',
#   'funny'],
#  ['uniteblue',
#   'abortion',
#   'talking',
#   'point',
#   'gopdebate',
#   'since',
#   'ppsellsbabyparts'],
#  ['k',
#   'mcq',
#   'closing',
#   'statements',
#   'reminisce',
#   'america',
#   'longer',
#   'exists',
#   'ted',
#   'kennedy',
#   '1965',
#   'immigration',
#   'nationality',
#   'act',
#   'g'],
#  ['lkwdcitizen',
#   'make',
#   'chris',
#   'christie',
#   'stopped',
#   'cleveland',
#   'ice',
#   'cream',
#   'shop',
#   'gopdebate',
#   'http',
#   'co',
#   'v8wvyfexx9'],
#  ['maureenjohnson',
#   'ted',
#   'cruz',
#   'going',
#   'personally',
#   'take',
#   'away',
#   'telescope',
#   'try',
#   'witch',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'killed',
#   'last',
#   'night',
#   'gopdebate',
#   'glad',
#   'cares',
#   'america',
#   'makeamericagreatagain'],
#  ['youngblkrepub',
#   'gopdebate',
#   'exciting',
#   'anything',
#   'else',
#   'tv',
#   'past',
#   '10',
#   'years'],
#  ['abbijacobson', 'shiiiittt', 'tough', 'say', 'making', 'horny', 'gopdebate'],
#  ['megynkelly',
#   'asked',
#   'realdonaldtrump',
#   'poor',
#   'questions',
#   'help',
#   'bush',
#   'polls',
#   'hannity',
#   'gopdebate',
#   'https',
#   'co',
#   'p389iile2n'],
#  ['bullriders1',
#   'olivianuzzi',
#   'daveweigel',
#   'gopdebate',
#   'better',
#   'thought',
#   'though',
#   'candidates',
#   'finessed',
#   'issues',
#   'sound',
#   'bytes'],
#  ['thebaxterbean',
#   'yes',
#   'marco',
#   'rubio',
#   'actually',
#   'said',
#   'iraq',
#   'invasion',
#   'mistake',
#   'http',
#   'co',
#   'xrowkhymm1',
#   'gopdebate',
#   'http',
#   'co',
#   'vjmjdm'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'voted',
#   'unemployment',
#   'benefits',
#   'even',
#   'though',
#   'florida',
#   'needs',
#   'http',
#   'co',
#   '2i6uolsctj',
#   'gopdebate',
#   'ht'],
#  ['jebbush',
#   'thoughtful',
#   'gopdebate',
#   'rethink911',
#   'http',
#   'co',
#   'k37hnbe2jy'],
#  ['thejimhughes',
#   'lot',
#   'jobs',
#   'available',
#   'bush',
#   'serves',
#   '2',
#   'terms',
#   'conservatives',
#   'committed',
#   'suicide',
#   'go'],
#  ['huh',
#   'watching',
#   'foxnews',
#   'debate',
#   '1',
#   'far',
#   'moderators',
#   'participants',
#   'better',
#   'gopdebate'],
#  ['3chicspolitico',
#   'donald',
#   'trump',
#   'insulted',
#   'megynkelly',
#   'women',
#   'one',
#   'man',
#   'stage',
#   'confronted',
#   'none',
#   'worthy'],
#  ['jjauthor',
#   'learjetter',
#   'waiting',
#   'megynkelly',
#   'ask',
#   'realdonaldtrump',
#   'stop',
#   'beating',
#   'wife',
#   'gopdebate',
#   'http'],
#  ['andreatantaros',
#   'last',
#   'night',
#   'watching',
#   'outnumberedfnc',
#   'got',
#   'ericbolling',
#   'good',
#   'stuff',
#   'gopdebate'],
#  ['renomarky',
#   'earth',
#   'megynkelly',
#   'aint',
#   'gopdebate',
#   'foxdebate',
#   'megynkelly',
#   'megynkellydebatequestions',
#   'http',
#   'co',
#   'yxhy'],
#  ['kesgardner',
#   'rand',
#   'paul',
#   'lands',
#   'first',
#   'haymaker',
#   'night',
#   'gopdebate'],
#  ['tarasetmayer',
#   'coming',
#   'wilkowmajority',
#   '1220pm',
#   'live',
#   'siriusxm',
#   'patriot125',
#   'post',
#   'gopdebate'],
#  ['republicans',
#   'like',
#   'rosie',
#   'donnell',
#   'icymi',
#   'frankluntz',
#   'gopdebate',
#   'debrief',
#   'cbsthismorning',
#   'http',
#   'co',
#   'nqiuiccolb'],
#  ['fff',
#   'highlights',
#   'week',
#   'include',
#   'nationalunderwearday',
#   'gopdebate',
#   'jonvoyage',
#   'officially',
#   'worst',
#   'week',
#   'ever',
#   'tgif'],
#  ['greenspaceguy',
#   'thedailyshow',
#   'jon',
#   'stewafeel',
#   'comfortable',
#   'w',
#   'retirement',
#   'gopdebate',
#   'solved',
#   'problems',
#   'personal',
#   'amp',
#   'scientific',
#   'htt'],
#  ['kesgardner',
#   'course',
#   'assclown',
#   'pledge',
#   'run',
#   'third',
#   'party',
#   'candidate',
#   'gopdebate'],
#  ['paul',
#   'krugman',
#   'sums',
#   'happended',
#   'last',
#   'night',
#   'one',
#   'two',
#   'major',
#   'parties',
#   'gone',
#   'deep',
#   'end',
#   'http',
#   'co',
#   'gkubem7ge7',
#   'gopdebate'],
#  ['eqphoto',
#   'remember',
#   'matter',
#   'wins',
#   'gopdebate',
#   'everyone',
#   'watched',
#   'loses',
#   'alcoholpoisoning'],
#  ['anthonymarlowe',
#   'trump',
#   'video',
#   'cost',
#   '4',
#   'times',
#   '700m',
#   'would',
#   'managed',
#   'realdonaldtrump',
#   'gopdebate',
#   'h'],
#  ['megynkelly', 'disgraced', 'last', 'night', 'gopdebate'],
#  ['proginosko',
#   'prediction',
#   'final',
#   'gopdebate',
#   'donald',
#   'trump',
#   'tear',
#   'missionimpossible',
#   'mask',
#   'reveal',
#   'smirking',
#   'jon',
#   'stewart'],
#  ['fallon',
#   'jon',
#   'stewaplease',
#   'come',
#   'back',
#   'alone',
#   'https',
#   'co',
# ...
#   'http',
#   'co',
#   'i4t3c2gmzo',
#   'via',
#   'sfgate'],
#  ['want',
#   'point',
#   'one',
#   'time',
#   'real',
#   'question',
#   'real',
#   'presidential',
#   'debate',
#   'god',
#   'say',
#   'gopdebate'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'constitutional',
#   'right',
#   'choose',
#   'egregiously',
#   'flawed',
#   'decision',
#   'http',
#   'co',
#   'u63wrh7mxn',
#   'gopdebate',
#   'http'],
#  ['scott',
#   'walker',
#   'wisconsin',
#   'seeing',
#   'fastest',
#   'shrinking',
#   'middle',
#   'class',
#   'america',
#   'http',
#   'co',
#   'zopokedb8l',
#   'gopdebate',
#   'votersfirst',
#   'trump2016'],
#  ['supporters',
#   'seem',
#   'care',
#   'corrupt',
#   'politicians',
#   'calls',
#   'stupid',
#   'gopdebate',
#   'https',
#   'co',
#   '8jnmnzszbk'],
#  ['gopdebate',
#   'carly',
#   'fiorina',
#   'called',
#   'hillary',
#   'liar',
#   '3x',
#   'hardball',
#   'chris',
#   '5',
#   'minutes',
#   'later',
#   'says',
#   'never',
#   'liar'],
#  ['know',
#   'audience',
#   'erupted',
#   'last',
#   'night',
#   'realdonaldtrump',
#   'rosie',
#   'line',
#   'ques',
#   'could',
#   'want',
#   'guy',
#   'prez',
#   'gopdebate'],
#  ['winners',
#   'gopdebate',
#   'sen',
#   'marcorubio',
#   'amp',
#   'former',
#   'hp',
#   'ceo',
#   'carlyfiorina',
#   'far',
#   'best',
#   'republican',
#   'presidential',
#   'candidates',
#   'http',
#   'co',
#   'v9qdpmpkk4'],
#  ['nancyleegrahn',
#   'gopdebate',
#   'giant',
#   'commercial',
#   'hillaryclinton',
#   'president',
#   'thank',
#   'god'],
#  ['daveanthony',
#   'chewbacca',
#   'roaring',
#   'every',
#   'would',
#   'fit',
#   'right',
#   'gopdebate'],
#  ['gopdebate',
#   'field',
#   'seems',
#   'terrified',
#   'mentioning',
#   'obama',
#   'negative',
#   'light'],
#  ['political',
#   'correctness',
#   'vile',
#   'term',
#   'people',
#   'invoke',
#   'slur',
#   'cowards',
#   'gopdebate',
#   'http',
#   'co',
#   'n8pu1zovbh'],
#  ['established',
#   'gopdebate',
#   'afraid',
#   'someone',
#   'willing',
#   'tell',
#   'truth',
#   'would',
#   'shake',
#   'dc',
#   'https',
#   'co',
#   'mia5t8yswp'],
#  ['writeintrump',
#   'knew',
#   'war',
#   'iraq',
#   'bad',
#   'idea',
#   'like',
#   'knew',
#   'letting',
#   'blind',
#   'guy',
#   'cut',
#   'rand',
#   'paul',
#   'hair',
#   'bad',
#   'idea',
#   'gop'],
#  ['yay', 'social', 'issues', 'next', 'gopdebate'],
#  ['artiswarusa',
#   'democrats',
#   'say',
#   'hail',
#   'hitlery',
#   'socialist',
#   'deathbydemocrat',
#   'election2016',
#   'stophillary',
#   'gopdebate',
#   'nazi',
#   'liberallogic',
#   'http'],
#  ['elevat0rlady',
#   'hopped',
#   'fb',
#   'saw',
#   'friends',
#   'recap',
#   'gopdebate',
#   'wins',
#   'http',
#   'co',
#   'tpszbvid8o'],
#  ['mammals',
#   'suck',
#   'shocked',
#   'hour',
#   'gopdebate',
#   'amp',
#   'qs',
#   'police',
#   'brutality',
#   'amp',
#   'blacklivesmatter'],
#  ['maybe',
#   'tweeting',
#   'game',
#   'know',
#   'let',
#   'spelling',
#   'contest',
#   'profanity',
#   'u',
#   'win',
#   'gopdebate',
#   'https',
#   'co',
#   '9taliqmezh'],
#  ['jeffsimmons2050',
#   'gopdebate',
#   'takeaway',
#   'presence',
#   'matters',
#   'see',
#   'presence',
#   'blend',
#   'believability',
#   'articulation',
#   'integrity',
#   'w',
#   'edg'],
#  ['carly',
#   'fiorina',
#   'runs',
#   'circles',
#   'around',
#   'chris',
#   'matthews',
#   'hillary',
#   'record',
#   'youtube',
#   'https',
#   'co',
#   'b9p8wg3ixz',
#   'gopdebate'],
#  ['jrehling',
#   'gopdebate',
#   'donald',
#   'trump',
#   'bruce',
#   'wayne',
#   'would',
#   'turned',
#   'parents',
#   'lived'],
#  ['jphoganorg',
#   'gopdebate',
#   'feelthebern',
#   'step',
#   'fallen',
#   'hillary2016',
#   'justice',
#   'fbi',
#   'fec',
#   'dissect',
#   '22nd',
#   'amendment',
#   'http'],
#  ['ali',
#   'compiled',
#   'chabased',
#   'polling',
#   'rank',
#   'versus',
#   'time',
#   'allotted',
#   'speak',
#   'gopdebate',
#   'walker',
#   'paul',
#   'robbed',
#   'http',
#   'co'],
#  ['gop',
#   'debate',
#   'campaign',
#   'preview',
#   'rearview',
#   'bradbannon',
#   'linkedin',
#   'https',
#   'co',
#   'n0mko8qqie',
#   'uniteblue',
#   'p2',
#   'potus',
#   'gopdebate',
#   'rsg15'],
#  ['richardhine',
#   'joe',
#   'biden',
#   'watching',
#   'gopdebate',
#   'http',
#   'co',
#   '6y2axgitms'],
#  ['american',
#   'women',
#   'take',
#   'note',
#   'realdonaldtrump',
#   'justified',
#   'piggish',
#   'attacks',
#   'women',
#   'gopdebate',
#   '1',
#   'man',
#   'stage',
#   'called'],
#  ['feministabulous',
#   'hate',
#   'abortion',
#   'defund',
#   'planned',
#   'parenthood',
#   'surefire',
#   'way',
#   'increase',
#   'abortion'],
#  ['leahrboss',
#   'carlyfiorina',
#   'spanked',
#   'boys',
#   'tonight',
#   'even',
#   'radar',
#   'gopdebate'],
#  ['indranibala',
#   'chris',
#   'christie',
#   'currently',
#   'using',
#   'case',
#   'bolster',
#   'campaign',
#   'presidency',
#   'gopdebate',
#   'https',
#   'co',
#   'ygmuldg8n2'],
#  ['jeb', 'looks', 'like', 'beavis', 'smiles', 'gopdebate'],
#  ['needs',
#   'comedy',
#   'shows',
#   'gopdebate',
#   'meanwhile',
#   'macdebate',
#   'kinda',
#   'snore',
#   'sorry',
#   'canada',
#   'https',
#   'co',
#   'qiqvue3fsr'],
#  ['thebaxterbean',
#   'reminder',
#   'family',
#   'important',
#   'republican',
#   '2016',
#   'candidates',
#   'gay',
#   'families',
#   'http',
#   'co',
#   'cs0usassqs',
#   'gopdebate',
#   'ht'],
#  ['debates',
#   'like',
#   'founding',
#   'fathers',
#   'less',
#   'like',
#   'game',
#   'shows',
#   'http',
#   'co',
#   '01kulhlxsk',
#   'gopdebate'],
#  ['berniesanders',
#   'scottwalker',
#   'man',
#   'say',
#   'one',
#   'intelligent',
#   'thing',
#   'mean',
#   'none',
#   'berniesanders',
#   'gopdebate',
#   'feelthebern'],
#  ['serious', 'gopdebate', 'hangover', 'today'],
#  ['cfjwagner',
#   '4',
#   'scariest',
#   'bugs',
#   'mean',
#   'gop',
#   'candidates',
#   'rimshot',
#   'http',
#   'co',
#   'okc1tfczww',
#   'gopdebate',
#   'blog',
#   'writerslife',
#   'http'],
#  ['marnus3',
#   'perfect',
#   'remedy',
#   'gopdebate',
#   'hangover',
#   'ff',
#   'pharris830',
#   'mharvey816',
#   'comebackdecade',
#   'glentheplumber',
#   'rfschatten'],
#  ['realdonaldtrump', 'got', 'trumped', 'megynkelly', 'gopdebate'],
#  ['mydaughtersarmy',
#   'debate',
#   'hard',
#   'ted',
#   'cruz',
#   'gopdebate',
#   'http',
#   'co',
#   '9hmr7num6n'],
#  ['keemstarx', 'black', 'guy', 'smafuck', 'gopdebate', 'trump', 'make', 'vp'],
#  ['thought', 'megynkelly', 'awesome', 'job', 'gopdebate', 'personally'],
#  ['megynkelly',
#   'u',
#   'disappointed',
#   'last',
#   'night',
#   'gopdebate',
#   'u',
#   'asked',
#   'realdonaldtrump',
#   'q',
#   'pertinent',
#   '2',
#   'duties',
#   'president'],
#  ['gahtbomb',
#   'mike',
#   'huckabee',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'gopdebate'],
#  ['ag',
#   'texas',
#   'hillary',
#   'clinton',
#   'response',
#   'gopdebate',
#   'guys',
#   'ok',
#   'secure',
#   'thousands',
#   'votes',
#   'illegals'],
#  ['writeintrump',
#   'every',
#   'time',
#   'bell',
#   'rings',
#   'rand',
#   'paul',
#   'little',
#   'poodle',
#   'ears',
#   'keep',
#   'perking',
#   'gopdebate'],
#  ['whinenot',
#   'rush',
#   'one',
#   '9',
#   'candidates',
#   'stage',
#   'joined',
#   'megan',
#   'kelly',
#   'going',
#   'donald',
#   'trump',
#   'gopdebate'],
#  ['writeintrump',
#   'rand',
#   'paul',
#   'haircut',
#   'really',
#   'distracting',
#   'almost',
#   'yelled',
#   'rand',
#   'get',
#   'leash',
#   'time',
#   'walk',
#   'gopdebate'],
#  ['tired',
#   'shills',
#   'media',
#   'hillary',
#   'henceforth',
#   'known',
#   'shillary',
#   'gopdebate'],
#  ['almightygod',
#   'ben',
#   'carson',
#   'god',
#   'pretty',
#   'fair',
#   'guy',
#   'guess',
#   'never',
#   'read',
#   'bible',
#   'job',
#   'pharaoh',
#   'shebears',
#   'gopdebate'],
#  ['writeintrump',
#   'cheap',
#   'tactic',
#   'rand',
#   'paul',
#   'getting',
#   'haircut',
#   'poodle',
#   'distract',
#   'gopdebate'],
#  ['theblaze',
#   'mattwalshblog',
#   'republicans',
#   'gopdebate',
#   'maybe',
#   'think',
#   'electing',
#   'someone',
#   'http',
#   'co',
#   'brx74ildwm'],
#  ['john',
#   'kasich',
#   'seems',
#   'like',
#   'decent',
#   'guy',
#   'pity',
#   'republican',
#   'gopdebate'],
#  ['gopdebate',
#   'bingo',
#   'atavist',
#   'https',
#   'co',
#   'hkew4f0kb2',
#   'http',
#   'co',
#   'pwaoz6kvop'],
#  ['rmconservative',
#   'cruz',
#   'line',
#   'campaignconservative',
#   'cuts',
#   '2',
#   'core',
#   'issue',
#   'gop',
#   'amp',
#   'also',
#   'shortcomings',
#   'gopdebate',
#   'htt'],
#  ['pulmyears',
#   'official',
#   'photo',
#   'big',
#   'foxnews',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '9yqgzvc2qv'],
#  ['last',
#   'night',
#   'gopdebate',
#   'proved',
#   'everything',
#   'already',
#   'knew',
#   'white',
#   'patriarchal',
#   'elitist',
#   'homophobic',
#   'party',
#   'gop'],
#  ['trump',
#   'integrity',
#   'character',
#   'principles',
#   'proud',
#   'mattwalshblog',
#   'agreed',
#   'gopdebate',
#   'trump'],
#  ['linnyitssn',
#   'also',
#   'funny',
#   'constitution',
#   'loving',
#   'republicans',
#   'structurally',
#   'violate',
#   'constitution',
#   'bringing',
#   'religion',
#   'politics',
#   'g'],
#  ['oaaselect',
#   'radical',
#   'capitalism',
#   'individual',
#   'rights',
#   'looking',
#   'heroic',
#   'candidate',
#   'gopdebate'],
#  ['blowtorch',
#   'irs',
#   'like',
#   'sound',
#   'criminalabusesnowpoised2policeourhealthcare',
#   'go',
#   'rick',
#   'gopdebate',
#   'https',
#   'co',
#   'zflcfhee3j'],
#  ['megynkelly', 'favorite', 'tonight', 'gopdebate', 'foxnews'],
#  ['gopdebate',
#   'fix',
#   'get',
#   'go',
#   'first',
#   'question',
#   'pledging',
#   'suppoaddressed',
#   'directly',
#   '2',
#   'realdonaldtrump'],
#  ['first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'uh06ezxxfg',
#   'socialmedia',
#   'smo'],
#  ['realbencarson',
#   'excellent',
#   'job',
#   'last',
#   'night',
#   'gopdebate',
#   'class',
#   'act',
#   'around',
#   'proud',
#   'republican',
#   'candidate',
#   'bencarson'],
#  ['korystamper',
#   'lookups',
#   'misogynist',
#   'spiking',
#   'merriamwebster',
#   'http',
#   'co',
#   'k7rbb12rlc',
#   'trump',
#   'women',
#   'gopdebate',
#   'http',
#   'co',
#   'yxsj'],
#  ['god',
#   'speaking',
#   'looney',
#   'tunes',
#   'real',
#   'questions',
#   'gopdebate',
#   'https',
#   'co',
#   'fbo00cn461'],
#  ['marcorubio',
#   'skye820',
#   'going',
#   'make',
#   'american',
#   'century',
#   'got',
#   'empower',
#   'small',
#   'businesses',
#   'thanks',
#   'question'],
#  ['pattonoswalt',
#   'god',
#   'named',
#   'bruce',
#   'springsteen',
#   'go',
#   'listen',
#   'jungleland',
#   'get',
#   'fucking',
#   'clue',
#   'christie',
#   'gopdebate'],
#  ['saw',
#   'megynkelly',
#   'reach',
#   'scratch',
#   'balls',
#   'picked',
#   '10th',
#   'fight',
#   'realdonaldtrump',
#   'gopdebate',
#   'tcot'],
#  ['thepatriot143',
#   'winner',
#   'overall',
#   'today',
#   'gopdebate',
#   'carlyfiorina',
#   'really',
#   'stood',
#   'among',
#   'gop',
#   'candidates'],
#  ['republicans',
#   'hate',
#   'gun',
#   'free',
#   'zones',
#   'held',
#   'gopdebate',
#   'gun',
#   'free',
#   'zone',
#   'https',
#   'co',
#   '0rlayowqw1'],
#  ['peddoc63',
#   'embassy',
#   'attacked',
#   'woman',
#   'would',
#   'trust',
#   'carlyfiorina',
#   'fav',
#   'hillaryclinton',
#   'gopdebate',
#   'http'],
#  ['lizadonnelly',
#   'political',
#   'nonsense',
#   'last',
#   'night',
#   'gopdebate',
#   'see',
#   'http',
#   'co',
#   'mocgzthbdz',
#   'site',
#   'https',
#   'co',
#   'xyahgrr5vh'],
#  ['teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'pry2qpcwfu'],
#  ['must',
#   'admit',
#   'realdonaldtrump',
#   'throws',
#   'shade',
#   'like',
#   'rhoa',
#   'lol',
#   'gopdebate',
#   'https',
#   'co',
#   'c9luq1dww3'],
#  ['looking',
#   'forward',
#   'listening',
#   'drshow',
#   'news',
#   'roundup',
#   'morning',
#   'look',
#   'away',
#   'gopdebate',
#   'http',
#   'co',
#   'o8rtitvgdt'],
#  ['molonlabe1776us',
#   'last',
#   'night',
#   'looked',
#   'megynkelly',
#   'bretbaier',
#   'gopdebate',
#   'tcot',
#   'realdonaldtrump',
#   'http',
#   'co',
#   'k2tk'],
#  ['know', 'laugh', 'cry', 'last', 'nights', 'gopdebate'],
#  ['pillary56',
#   'difference',
#   'politically',
#   'correct',
#   'massive',
#   'jerk',
#   'mr',
#   'trump',
#   'gopdebate'],
#  ['thoughts',
#   'perry',
#   'fiorina',
#   'must',
#   'replace',
#   'paul',
#   'kasich',
#   'top',
#   'ten',
#   'jindal',
#   'needs',
#   'step',
#   'replace',
#   'christie',
#   'gopdebate'],
#  ['marcorubio', 'nominee', 'party', 'future', 'gopdebate'],
#  ['sentedcruz',
#   'best',
#   'answer',
#   'night',
#   'response',
#   'immigration',
#   'stupidity',
#   'sides',
#   'want',
#   'gopdebate'],
#  ['thebloggess',
#   'rather',
#   'watching',
#   'gopdebate',
#   'watching',
#   'maureenjohnson',
#   'live',
#   'tweet',
#   'made',
#   'right',
#   'decision',
#   'https'],
#  ['interesting',
#   'gopdebate',
#   'analysis',
#   'marcorubio',
#   'clearly',
#   'excelled',
#   'conservative',
#   'leader',
#   'need',
#   'go',
#   'teammarco',
#   'tcot',
#   'https',
#   'co',
#   'pve8wuodke'],
#  ['krauthammer',
#   'sorry',
#   'downfall',
#   'trump',
#   'last',
#   'nights',
#   'debate',
#   'greatly',
#   'exaggerated',
#   'gopdebate'],
#  ['moderator',
#   'scottwalker',
#   'rip',
#   'iran',
#   'deal',
#   'day',
#   '1',
#   'walker',
#   'remember',
#   'tying',
#   'yellow',
#   'ribbons',
#   'trees',
#   'gopdebate'],
#  ['ccalbos',
#   'tell',
#   'us',
#   'god',
#   'speaks',
#   'happening',
#   'real',
#   'life',
#   'gopdebate'],
#  ['gusramsey', 'snl', 'big', 'enough', 'cast', 'spoof', 'gopdebate'],
#  ['bbcworld',
#   'bbcjonsopel',
#   'midst',
#   'gopdebate',
#   'came',
#   'big',
#   'blow',
#   'barackobama',
#   'announcement',
#   'leading',
#   'jewish',
#   'democrat',
#   'sen',
#   'schumer'],
#  ['ccalbos',
#   'huckabee',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'behalf',
#   'military',
#   'families',
#   'f',
#   'gopdebate'],
#  ['perezhilton',
#   'watching',
#   'gopdebate',
#   'hillaryclinton',
#   'taking',
#   'selfies',
#   'kimkardashian',
#   'http',
#   'co',
#   'hytsdemr64',
#   'http'],
#  ['realbencarson',
#   'pre',
#   'gopdebate',
#   'ritual',
#   'bc2dc16',
#   'https',
#   'co',
#   'agbmc4nbm5'],
#  ['realdonaldtrump',
#   'arrogance',
#   'gopdebate',
#   'used',
#   'laws',
#   'country',
#   'advantage',
#   'notthatguy',
#   'http',
#   'co',
#   'rjtjr9ioac'],
#  ['18',
#   'hours',
#   'later',
#   'looking',
#   'back',
#   'biggest',
#   'gaffe',
#   'gopdebate',
#   'repeatedly',
#   'tagging',
#   'victor',
#   'cruz',
#   'teamvic',
#   'instead',
#   'ted',
#   'cruz',
#   'tedcruz'],
#  ['real',
#   'scary',
#   'liberals',
#   'allowed',
#   '2',
#   'walk',
#   'around',
#   'committing',
#   'horrific',
#   'crimes',
#   'humanity',
#   'gopdebate',
#   'plannedbutcherhood'],
#  ['like',
#   'thank',
#   '9',
#   'candidates',
#   'gopdebate',
#   'took',
#   'trump',
#   'task',
#   'trying',
#   'fatshame',
#   'rosie'],
#  ['got', 'ta', 'love', 'megynkelly', 'gopdebate'],
#  ['numbersmuncher',
#   'donald',
#   'trump',
#   'guy',
#   'flips',
#   'risk',
#   'board',
#   'realizes',
#   'overtake',
#   'asia',
#   'gopdebate'],
#  ['brendohare',
#   'great',
#   'battle',
#   'last',
#   'night',
#   'premier',
#   'teenage',
#   'athletes',
#   'gopdebate',
#   'http',
#   'co',
#   'plgp4aai2y'],
#  ['foxnews',
#   'replace',
#   'megynkelly',
#   'marthamaccallum',
#   'future',
#   'debates',
#   'maccallum',
#   'much',
#   'better',
#   'job',
#   'early',
#   'debate',
#   'gopdebate'],
#  ['donald',
#   'trump',
#   'democratic',
#   'spy',
#   'http',
#   'co',
#   '8n9mvtkn4u',
#   'realdonaldtrump',
#   'sensanders',
#   'trump',
#   'donaldtrump',
#   'hillary2016',
#   'gopdebate'],
#  ['jjosephwilliams',
#   '16',
#   'united',
#   'states',
#   'homes',
#   'tv',
#   'sets',
#   'tuned',
#   'gopdebate',
#   'wow',
#   'http',
#   'co',
#   'trs8vmwjyg'],
#  ['gopdebate',
#   'old',
#   'white',
#   'rich',
#   'conservative',
#   'dudes',
#   'parade',
#   'childhood',
#   'nightmare',
#   'mine'],
#  ['ljcambria',
#   'realdonaldtrump',
#   'forget',
#   'vote',
#   'especislly',
#   'go',
#   'independent',
#   'lulz',
#   'huckster',
#   'rnc',
#   'gop',
#   'gopdebate'],
#  ['recap',
#   'gopdebate',
#   'tenmen',
#   'want',
#   'make',
#   'choices',
#   'women',
#   'goptbt',
#   'http',
#   'co',
#   'v1desifyee'],
#  ['writeintrump',
#   'made',
#   'hillary',
#   'clinton',
#   'go',
#   'wedding',
#   'also',
#   'made',
#   'best',
#   'man',
#   'gopdebate'],
#  ['rand',
#   'paul',
#   'could',
#   'drop',
#   'top',
#   '10',
#   'w',
#   'dreadful',
#   'petulent',
#   'debate',
#   'fiorina',
#   'moves',
#   'gopdebate',
#   'tcot'],
#  ['nerdist',
#   'got',
#   'ta',
#   'say',
#   'refreshing',
#   'hear',
#   'presidential',
#   'debate',
#   'everyone',
#   'correctly',
#   'pronouncing',
#   'nuclear',
#   'gopdebate'],
#  ['gogoaleee',
#   'ig',
#   'deleted',
#   'dd',
#   'account',
#   'participated',
#   'kkkorgop',
#   'hashtag',
#   'gopdebate',
#   'http',
#   'co',
#   'jnyrnopngx',
#   'via',
#   'dream'],
#  ['crazyclarine',
#   'lol',
#   'the3o5flyguy',
#   'watching',
#   'gopdebate',
#   'like',
#   'http',
#   'co',
#   'zowjcu2baz'],
#  ['sjadetx', 'thoughts', 'gopdebate', 'http', 'co', 'bt7glnyuon'],
#  ['freedomtexasmom',
#   'love',
#   'megynkelly',
#   'died',
#   'tonight',
#   'gopdebate',
#   'foxnews',
#   'trumpcruz2016',
#   'makeamericagreatagain'],
#  ...]

# %%
#feature extraction using word2vec
model = Word2Vec(corpus, size=100, window=5, min_count=1)

# %%
#vocabulary list
model.wv.vocab
# Out:
# {'nancyleegrahn': <gensim.models.keyedvectors.Vocab at 0x7fcbd2c9c748>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7fcbd2c9c7b8>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7fcb78c90f28>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x7fcb78c90e48>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fcb78c90d68>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7fcb78c90c50>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fcb78c90da0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9048>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9080>,
#  'gopdebate': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca90b8>,
#  'scottwalker': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca90f0>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9128>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9160>,
#  'scott': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9198>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca91d0>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9208>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9240>,
#  'seconds': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9278>,
#  'walker16': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca92b0>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca92e8>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9320>,
#  'zsff': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9358>,
#  'tjmshow': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9390>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca93c8>,
#  'tamir': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9400>,
#  'rice': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9438>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9470>,
#  'cleveland': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca94a8>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca94e0>,
#  'robgeorge': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9518>,
#  'carly': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9550>,
#  'fiorina': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9588>,
#  'trending': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca95c0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca95f8>,
#  'debate': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9630>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9668>,
#  'completed': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca96a0>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca96d8>,
#  'danscavino': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9710>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9748>,
#  'realdonaldtrump': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9780>,
#  'delivered': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca97b8>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca97f0>,
#  'ratings': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9828>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9860>,
#  'presidential': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9898>,
#  'debates': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca98d0>,
#  'trump2016': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9908>,
#  'gregabbott': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9940>,
#  'tx': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9978>,
#  'tedcruz': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca99b0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca99e8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9a20>,
#  'rescind': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9a58>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9a90>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9ac8>,
#  'executive': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9b00>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9b38>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9b70>,
#  'barack': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9ba8>,
#  'obama': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9be0>,
#  'foxnews': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9c18>,
#  'warriorwoman91': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9c50>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9c88>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9cc0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9cf8>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9d30>,
#  'moderator': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9d68>,
#  'anymore': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9da0>,
#  'megynkelly': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9dd8>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9e10>,
#  'msnbc': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9e48>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9e80>,
#  'thomasaroberts': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9eb8>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9ef0>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9f28>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9f60>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9f98>,
#  'deer': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca9fd0>,
#  'headlights': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6048>,
#  'lizzwinstead': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6080>,
#  'ben': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca60b8>,
#  'carson': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca60f0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6128>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6160>,
#  'surgeon': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6198>,
#  'performed': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca61d0>,
#  'lobotomy': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6208>,
#  'nancyosborne180': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6240>,
#  'proved': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6278>,
#  'batsask': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca62b0>,
#  'badassteachersa': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca62e8>,
#  'tbats': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6320>,
#  'g2ggjy1bjd': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6358>,
#  'jgreendc': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6390>,
#  'fairness': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca63c8>,
#  'billclinton': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6400>,
#  'owns': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6438>,
#  'phrase': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6470>,
#  'waynedupreeshow': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca64a8>,
#  'woke': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca64e0>,
#  'tweet': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6518>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6550>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6588>,
#  'govmikehuckabee': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca65c0>,
#  '6ov5hxhicv': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca65f8>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6630>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6668>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca66a0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca66d8>,
#  'giagjpygxz': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6710>,
#  'arcticfox2016': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6748>,
#  'allenwestrepub': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6780>,
#  'dear': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca67b8>,
#  'jebbush': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca67f0>,
#  'notamistake': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6828>,
#  'ttfg7kycd9': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6860>,
#  'pattonoswalt': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6898>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca68d0>,
#  'walker': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6908>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6940>,
#  'harmon': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6978>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca69b0>,
#  'rival': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca69e8>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6a20>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6a58>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6a90>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6ac8>,
#  'chrischristie': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6b00>,
#  'exploiting': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6b38>,
#  'tragedy': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6b70>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6ba8>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6be0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6c18>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6c50>,
#  'rudygiulianigop': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6c88>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6cc0>,
#  'carolcnn': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6cf8>,
#  'donaldtrump': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6d30>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6d68>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6da0>,
#  'peterbeinasl': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6dd8>,
#  'schaeffer': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6e10>,
#  'iwf': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6e48>,
#  'myrkiger': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6e80>,
#  'weigh': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6eb8>,
#  'johncardillo': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6ef0>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6f28>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6f60>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6f98>,
#  'moderators': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca6fd0>,
#  '31': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8048>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8080>,
#  '2wsut0c0lx': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca80b8>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca80f0>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8128>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8160>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8198>,
#  'ignorant': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca81d0>,
#  'gop': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8208>,
#  'tcot': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8240>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8278>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca82b0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca82e8>,
#  'pamelageller': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8320>,
#  'huckabee': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8358>,
#  'paying': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8390>,
#  'transgender': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca83c8>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8400>,
#  'soldiers': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8438>,
#  'sailors': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8470>,
#  'airmen': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca84a8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca84e0>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8518>,
#  'safer': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8550>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8588>,
#  'chucknellis': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca85c0>,
#  'cruz': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca85f8>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8630>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8668>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca86a0>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca86d8>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8710>,
#  'mchamric': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8748>,
#  'teatraitors': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8780>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca87b8>,
#  'clown': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca87f0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8828>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8860>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8898>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca88d0>,
#  'helping': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8908>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8940>,
#  'nwgx8g8jwr': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8978>,
#  'erinmallorylong': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca89b0>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca89e8>,
#  'planned': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8a20>,
#  'parenthood': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8a58>,
#  'thekevinryder': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8a90>,
#  'vine': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8ac8>,
#  'dabulldawg88': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8b00>,
#  'xkxvdradce': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8b38>,
#  'mrpooni': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8b70>,
#  'fox': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8ba8>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8be0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8c18>,
#  'convince': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8c50>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8c88>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8cc0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8cf8>,
#  'americans': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8d30>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8d68>,
#  'isis': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8da0>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8dd8>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8e10>,
#  'rankings': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8e48>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8e80>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8eb8>,
#  'rubio': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8ef0>,
#  'kasich': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8f28>,
#  'christie': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8f60>,
#  'bush': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8f98>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x7fcb78ca8fd0>,
#  'thebaxterbean': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced048>,
#  'abortion': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced080>,
#  'ban': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced0b8>,
#  'allows': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced0f0>,
#  'rapist': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced128>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced160>,
#  'sue': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced198>,
#  'emotional': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced1d0>,
#  'distress': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced208>,
#  'rhmvgumuir': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced240>,
#  'badger': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced278>,
#  'feministabulous': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced2b0>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced2e8>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced320>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced358>,
#  'gay': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced390>,
#  'rights': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced3c8>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced400>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced438>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced470>,
#  'mch7576': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced4a8>,
#  'pry2qpcwfu': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced4e0>,
#  'hillaryclinton': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced518>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced550>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced588>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced5c0>,
#  'donating': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced5f8>,
#  'democrat': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced630>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced668>,
#  'pglqcqqgop': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced6a0>,
#  'qp1e': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced6d8>,
#  'fbhw': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced710>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced748>,
#  'borrow': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced780>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced7b8>,
#  'horn': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced7f0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced828>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced860>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced898>,
#  'wimpy': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced8d0>,
#  'hornmeansyouredone': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced908>,
#  'lisavikingstad': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced940>,
#  'ted': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced978>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced9b0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7fcb78ced9e8>,
#  'confusingly': <gensim.models.keyedvectors.Vocab at 0x7fcb78ceda20>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7fcb78ceda58>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7fcb78ceda90>,
#  'refuse': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedac8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedb00>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedb38>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedb70>,
#  'x6kuvskltf': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedba8>,
#  'socialmedia': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedbe0>,
#  'ogoyfnyikj': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedc18>,
#  'winesdaypodcast': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedc50>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedc88>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedcc0>,
#  'failures': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedcf8>,
#  'fgglf2j5hu': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedd30>,
#  'zw35dkuozi': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedd68>,
#  'amymek': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedda0>,
#  'torched': <gensim.models.keyedvectors.Vocab at 0x7fcb78ceddd8>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x7fcb78cede10>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x7fcb78cede48>,
#  'candycrowley': <gensim.models.keyedvectors.Vocab at 0x7fcb78cede80>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedeb8>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedef0>,
#  'assassin': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedf28>,
#  'congratulations': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedf60>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedf98>,
#  'wi': <gensim.models.keyedvectors.Vocab at 0x7fcb78cedfd0>,
#  'stockwizards3': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0048>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0080>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf00b8>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf00f0>,
#  'landslide': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0128>,
#  'seanhannity': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0160>,
#  'anncoulter': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0198>,
#  'republican': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf01d0>,
#  'potus': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0208>,
#  'kvxrdashian': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0240>,
#  'jeb': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0278>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf02b0>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf02e8>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0320>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0358>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0390>,
#  'ali': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf03c8>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0400>,
#  'voters': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0438>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0470>,
#  'wiser': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf04a8>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf04e0>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0518>,
#  'folks': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0550>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0588>,
#  'forth': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf05c0>,
#  'journalism': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf05f8>,
#  'itsashlyperez': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0630>,
#  'listening': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0668>,
#  'fetty': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf06a0>,
#  'wap': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf06d8>,
#  'packing': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0710>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0748>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0780>,
#  'doesthishashtagexpire': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf07b8>,
#  'mgell': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf07f0>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0828>,
#  'shrug': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0860>,
#  'emoji': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0898>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf08d0>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0908>,
#  'lego': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0940>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0978>,
#  'jamellemybelle': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf09b0>,
#  'meanwhile': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf09e8>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0a20>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0a58>,
#  'nouuut5hkq': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0a90>,
#  'rowdygentleman': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0ac8>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0b00>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0b38>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0b70>,
#  'rowdy': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0ba8>,
#  'gentleman': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0be0>,
#  'brownblaze': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0c18>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0c50>,
#  'kkkorgop': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0c88>,
#  'yaqyac3uv3': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0cc0>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0cf8>,
#  'criticism': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0d30>,
#  'misogynistic': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0d68>,
#  'remarks': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0da0>,
#  'correctness': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0dd8>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0e10>,
#  'nope': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0e48>,
#  'pervasive': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0e80>,
#  'sexism': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0eb8>,
#  'lekarmasucre': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0ef0>,
#  'handled': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0f28>,
#  'blacklivesmatter': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0f60>,
#  '8zgdy6lpct': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0f98>,
#  'palmaceiahome1': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf0fd0>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4048>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4080>,
#  'pave': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf40b8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf40f0>,
#  'rino': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4128>,
#  'philstockworld': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4160>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4198>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf41d0>,
#  'futures': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4208>,
#  'spy': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4240>,
#  'nonfarmpayrolls': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4278>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf42b0>,
#  'netflix': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf42e8>,
#  '0k06sf81rq': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4320>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4358>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4390>,
#  'gov': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf43c8>,
#  'tweeted': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4400>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4438>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4470>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf44a8>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf44e0>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4518>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4550>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4588>,
#  'trans': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf45c0>,
#  'servicemembers': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf45f8>,
#  'ariannahuff': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4630>,
#  'yki30j7hho': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4668>,
#  'chrisstirewalt': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf46a0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf46d8>,
#  'moments': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4710>,
#  'randpaul': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4748>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4780>,
#  'kellyfil': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf47b8>,
#  'stylemom': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf47f0>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4828>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4860>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4898>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf48d0>,
#  'foh': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4908>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4940>,
#  '1965': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4978>,
#  'wtf': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf49b0>,
#  'rushlimbaugh': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf49e8>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4a20>,
#  'beheaded': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4a58>,
#  'overseas': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4a90>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4ac8>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4b00>,
#  'rosie': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4b38>,
#  'donnell': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4b70>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4ba8>,
#  'defend': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4be0>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4c18>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4c50>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4c88>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4cc0>,
#  'juvenile': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4cf8>,
#  'theskysgoneout': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4d30>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4d68>,
#  'christians': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4da0>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4dd8>,
#  'questions': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4e10>,
#  'underline': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4e48>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4e80>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4eb8>,
#  'cares': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4ef0>,
#  'religious': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4f28>,
#  'minorities': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4f60>,
#  'chri': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4f98>,
#  'bipartisanism': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf4fd0>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7048>,
#  'pathetic': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7080>,
#  'ismxbrrm0h': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf70b8>,
#  'factcheckdotorg': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf70f0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7128>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7160>,
#  'fl': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7198>,
#  'taxes': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf71d0>,
#  '19b': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7208>,
#  'includes': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7240>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7278>,
#  'estate': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf72b0>,
#  'mandated': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf72e8>,
#  'federal': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7320>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7358>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7390>,
#  'mydaughtersarmy': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf73c8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7400>,
#  'abortions': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7438>,
#  'rbl1t4ipx6': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7470>,
#  'karrattipaul': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf74a8>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf74e0>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7518>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7550>,
#  'warrant': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7588>,
#  'signed': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf75c0>,
#  'wakeupamerica': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf75f8>,
#  'cruzcrew': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7630>,
#  'htt': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7668>,
#  'p0tus': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf76a0>,
#  'closing': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf76d8>,
#  'statements': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7710>,
#  's15nlillso': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7748>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7780>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf77b8>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf77f0>,
#  'goodbye': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7828>,
#  'bretbaier': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7860>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7898>,
#  'wallace': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf78d0>,
#  'frankluntz': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7908>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7940>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7978>,
#  'groupers': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf79b0>,
#  'favorable': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf79e8>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7a20>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7a58>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7a90>,
#  'positively': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7ac8>,
#  'holly': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7b00>,
#  'renee': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7b38>,
#  'donation': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7b70>,
#  'carlyfiorina': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7ba8>,
#  'impressed': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7be0>,
#  'jlfhfvz7st': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7c18>,
#  'thejimhughes': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7c50>,
#  'sending': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7c88>,
#  'foreign': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7cc0>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7cf8>,
#  'places': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7d30>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7d68>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7da0>,
#  'staberkeley': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7dd8>,
#  'frankthorpnbc': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7e10>,
#  'rand': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7e48>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7e80>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7eb8>,
#  'hf318qsowd': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7ef0>,
#  'johnkasich': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7f28>,
#  'scrap': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7f60>,
#  'iran': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7f98>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7fcb78cf7fd0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb048>,
#  'nuke': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb080>,
#  'kasich4us': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb0b8>,
#  '9trzxonlzf': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb0f0>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb128>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb160>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb198>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb1d0>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb208>,
#  'fulltime': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb240>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb278>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb2b0>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb2e8>,
#  'closer': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb320>,
#  'election': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb358>,
#  'hooked': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb390>,
#  'mspackyetti': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb3c8>,
#  'donald': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb400>,
#  'campaign': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb438>,
#  'reveals': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb470>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb4a8>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb4e0>,
#  'trolls': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb518>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb550>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb588>,
#  'eve': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb5c0>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb5f8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb630>,
#  'elected': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb668>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb6a0>,
#  'george': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb6d8>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb710>,
#  'agenda': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb748>,
#  'promote': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb780>,
#  'fired': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb7b8>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb7f0>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb828>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb860>,
#  '9k1eujdfo7': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb898>,
#  'hlllary': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb8d0>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb908>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb940>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb978>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb9b0>,
#  'affordable': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfb9e8>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfba20>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfba58>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfba90>,
#  'naughtybeyotch': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbac8>,
#  'wqnsupspkc': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbb00>,
#  'marthamaccallum': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbb38>,
#  'billhemmer': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbb70>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbba8>,
#  'martha': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbbe0>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbc18>,
#  '2nd': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbc50>,
#  'ambush': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbc88>,
#  'megyn': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbcc0>,
#  'kelly': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbcf8>,
#  'attacking': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbd30>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbd68>,
#  'franklin': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbda0>,
#  'graham': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbdd8>,
#  '1st': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbe10>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbe48>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbe80>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbeb8>,
#  'candidates': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbef0>,
#  'express': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbf28>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbf60>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbf98>,
#  'jesus': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfbfd0>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe048>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe080>,
#  'snarkydemo': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe0b8>,
#  'politically': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe0f0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe128>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe160>,
#  'trumpspeak': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe198>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe1d0>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe208>,
#  'asshole': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe240>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe278>,
#  'wfk5cmvgin': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe2b0>,
#  'davidcicilline': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe2e8>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe320>,
#  'apprentice': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe358>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe390>,
#  'luntz': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe3c8>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe400>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe438>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe470>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe4a8>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe4e0>,
#  'dial': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe518>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe550>,
#  'lolhayley': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe588>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe5c0>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe5f8>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe630>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe668>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe6a0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe6d8>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe710>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe748>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe780>,
#  'transplant': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe7b8>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe7f0>,
#  'mtaibbi': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe828>,
#  'brandondhowell': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe860>,
#  'stafriday': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe898>,
#  '1ai9cuz8by': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe8d0>,
#  'unconstitutional': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe908>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe940>,
#  'enacted': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe978>,
#  'pres': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe9b0>,
#  'oba': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfe9e8>,
#  'ronnie2k': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfea20>,
#  'jcuirk1i1u': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfea58>,
#  'bruneski': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfea90>,
#  'upstairs': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeac8>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeb00>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeb38>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeb70>,
#  'gopclowncar': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeba8>,
#  'todd': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfebe0>,
#  'akin': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfec18>,
#  'sting': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfec50>,
#  'backfired': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfec88>,
#  'republicans': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfecc0>,
#  'standwithpp': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfecf8>,
#  'ekxpfkthqn': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfed30>,
#  'learjetter': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfed68>,
#  'digest': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeda0>,
#  'allowing': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfedd8>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfee10>,
#  'dwstweets': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfee48>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfee80>,
#  'ladysandersfarm': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeeb8>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfeef0>,
#  'enormous': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfef28>,
#  'applause': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfef60>,
#  'horribly': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfef98>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7fcb78cfefd0>,
#  'r4e8tpotd5': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01048>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01080>,
#  'responses': <gensim.models.keyedvectors.Vocab at 0x7fcb78d010b8>,
#  '2iqcdrcdlm': <gensim.models.keyedvectors.Vocab at 0x7fcb78d010f0>,
#  '7tdma3vlm8': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01128>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01160>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01198>,
#  'conservative': <gensim.models.keyedvectors.Vocab at 0x7fcb78d011d0>,
#  'reporter': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01208>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01240>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01278>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7fcb78d012b0>,
#  'kingsthings': <gensim.models.keyedvectors.Vocab at 0x7fcb78d012e8>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01320>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01358>,
#  'opportunities': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01390>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7fcb78d013c8>,
#  'answering': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01400>,
#  'candidate': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01438>,
#  'melissagracey': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01470>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7fcb78d014a8>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x7fcb78d014e0>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01518>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01550>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01588>,
#  'icredssplr': <gensim.models.keyedvectors.Vocab at 0x7fcb78d015c0>,
#  'reince': <gensim.models.keyedvectors.Vocab at 0x7fcb78d015f8>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01630>,
#  'incredible': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01668>,
#  'apxm8ao8jf': <gensim.models.keyedvectors.Vocab at 0x7fcb78d016a0>,
#  'doubled': <gensim.models.keyedvectors.Vocab at 0x7fcb78d016d8>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01710>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01748>,
#  'watched': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01780>,
#  'katethomas': <gensim.models.keyedvectors.Vocab at 0x7fcb78d017b8>,
#  'literally': <gensim.models.keyedvectors.Vocab at 0x7fcb78d017f0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01828>,
#  'lousy': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01860>,
#  'hangover': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01898>,
#  'cxch7x': <gensim.models.keyedvectors.Vocab at 0x7fcb78d018d0>,
#  'dreamer': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01908>,
#  'haha': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01940>,
#  'saas': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01978>,
#  'voxdotcom': <gensim.models.keyedvectors.Vocab at 0x7fcb78d019b0>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7fcb78d019e8>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01a20>,
#  'factchecked': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01a58>,
#  'daectmllaj': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01a90>,
#  'texascruzn': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01ac8>,
#  '1z3vufjzlw': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01b00>,
#  'zellieimani': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01b38>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01b70>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01ba8>,
#  'qlgsxrh5hw': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01be0>,
#  'marco': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01c18>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01c50>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01c88>,
#  'anti': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01cc0>,
#  'bigotry': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01cf8>,
#  'a4eiuettlf': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01d30>,
#  'cariisie': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01d68>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01da0>,
#  'foolish': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01dd8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01e10>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01e48>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01e80>,
#  'crying': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01eb8>,
#  'agai': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01ef0>,
#  'akbarjenkins': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01f28>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01f60>,
#  'piven': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01f98>,
#  'cloward': <gensim.models.keyedvectors.Vocab at 0x7fcb78d01fd0>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06048>,
#  'pinkard': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06080>,
# ...
#  'ohioans': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06710>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06748>,
#  '350': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06780>,
#  '000': <gensim.models.keyedvectors.Vocab at 0x7fcb78d067b8>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fcb78d067f0>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06828>,
#  'kbzfbjyp2c': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06860>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06898>,
#  'maryknoll': <gensim.models.keyedvectors.Vocab at 0x7fcb78d068d0>,
#  'sisters': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06908>,
#  'replace': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06940>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06978>,
#  'convent': <gensim.models.keyedvectors.Vocab at 0x7fcb78d069b0>,
#  'fdgxg3vv13': <gensim.models.keyedvectors.Vocab at 0x7fcb78d069e8>,
#  'catholic': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06a20>,
#  'gofundme': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06a58>,
#  'trcot': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06a90>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06ac8>,
#  'audience': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06b00>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06b38>,
#  'nzync1jrxs': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06b70>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06ba8>,
#  'violently': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06be0>,
#  '69ing': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06c18>,
#  'cameronesposito': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06c50>,
#  'ugh': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06c88>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06cc0>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06cf8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06d30>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06d68>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06da0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06dd8>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06e10>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06e48>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06e80>,
#  'attacked': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06eb8>,
#  'congoboy': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06ef0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06f28>,
#  'tiring': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06f60>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06f98>,
#  'shockingly': <gensim.models.keyedvectors.Vocab at 0x7fcb78d06fd0>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09048>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09080>,
#  'vtk1k0txi': <gensim.models.keyedvectors.Vocab at 0x7fcb78d090b8>,
#  'blessed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d090f0>,
#  'thedemocrats': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09128>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09160>,
#  'marcorubio': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09198>,
#  'miracle': <gensim.models.keyedvectors.Vocab at 0x7fcb78d091d0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09208>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09240>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09278>,
#  'lnqhdgtudk': <gensim.models.keyedvectors.Vocab at 0x7fcb78d092b0>,
#  'mattyiceaz': <gensim.models.keyedvectors.Vocab at 0x7fcb78d092e8>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09320>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09358>,
#  'xlnb': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09390>,
#  'indication': <gensim.models.keyedvectors.Vocab at 0x7fcb78d093c8>,
#  'peep': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09400>,
#  'bh0chsy5eh': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09438>,
#  'smethanie': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09470>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7fcb78d094a8>,
#  'tooth': <gensim.models.keyedvectors.Vocab at 0x7fcb78d094e0>,
#  'fairy': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09518>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09550>,
#  'teletubbies': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09588>,
#  'voted': <gensim.models.keyedvectors.Vocab at 0x7fcb78d095c0>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7fcb78d095f8>,
#  'caller': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09630>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09668>,
#  'limbaugh': <gensim.models.keyedvectors.Vocab at 0x7fcb78d096a0>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7fcb78d096d8>,
#  'stinger': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09710>,
#  'inc': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09748>,
#  'behaviour': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09780>,
#  'astonishingly': <gensim.models.keyedvectors.Vocab at 0x7fcb78d097b8>,
#  'biased': <gensim.models.keyedvectors.Vocab at 0x7fcb78d097f0>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09828>,
#  'wins': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09860>,
#  'falters': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09898>,
#  'exaggerates': <gensim.models.keyedvectors.Vocab at 0x7fcb78d098d0>,
#  'molloaqhwq': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09908>,
#  'knowmorenotless': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09940>,
#  'gpnaplang': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09978>,
#  'jamesviser': <gensim.models.keyedvectors.Vocab at 0x7fcb78d099b0>,
#  'huh': <gensim.models.keyedvectors.Vocab at 0x7fcb78d099e8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09a20>,
#  'clinton': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09a58>,
#  'charity': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09a90>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09ac8>,
#  'clintons': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09b00>,
#  'bvwrosgwal': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09b38>,
#  'copolitics': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09b70>,
#  'hillary2016': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09ba8>,
#  'stophillary': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09be0>,
#  'uniteb': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09c18>,
#  'kraig4u': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09c50>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09c88>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09cc0>,
#  'seriously': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09cf8>,
#  'heidil': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09d30>,
#  'rn': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09d68>,
#  'diegouk': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09da0>,
#  'democrats': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09dd8>,
#  '7v4wjok3vm': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09e10>,
#  'p2': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09e48>,
#  'ctl': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09e80>,
#  'topprog': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09eb8>,
#  'tlot': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09ef0>,
#  'owe': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09f28>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09f60>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09f98>,
#  'exposing': <gensim.models.keyedvectors.Vocab at 0x7fcb78d09fd0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d048>,
#  'rhinos': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d080>,
#  'lies': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d0b8>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d0f0>,
#  '535m': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d128>,
#  'surplus': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d160>,
#  '76b': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d198>,
#  'deficit': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d1d0>,
#  'vvmxzkxlkr': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d208>,
#  'sensanders': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d240>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d278>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d2b0>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d2e8>,
#  '5hkcefp1hf': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d320>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d358>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d390>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d3c8>,
#  'sandwich': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d400>,
#  'frankconniff': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d438>,
#  'interviewer': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d470>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d4a8>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d4e0>,
#  'feeding': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d518>,
#  'lesliemac': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d550>,
#  'murder': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d588>,
#  'ppl': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d5c0>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d5f8>,
#  'unborn': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d630>,
#  'babies': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d668>,
#  'goplogic': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d6a0>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d6d8>,
#  'jon': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d710>,
#  'stewaalready': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d748>,
#  'jonvoyage': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d780>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d7b8>,
#  'charlottelaws': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d7f0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d828>,
#  'libertyjibbet': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d860>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d898>,
#  'whine': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d8d0>,
#  'unfair': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d908>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d940>,
#  'ya': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d978>,
#  'gopde': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d9b0>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0d9e8>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0da20>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0da58>,
#  'forkedtongue': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0da90>,
#  'iseeorangepeople': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dac8>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0db00>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0db38>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0db70>,
#  'destroying': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dba8>,
#  'kellyfai': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dbe0>,
#  'edstetzer': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dc18>,
#  'btw': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dc50>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dc88>,
#  'politics': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dcc0>,
#  'religion': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dcf8>,
#  'teammarco': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dd30>,
#  'nailed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dd68>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dda0>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0ddd8>,
#  'nn6s7do22j': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0de10>,
#  'bankruptcy': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0de48>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0de80>,
#  'softball': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0deb8>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0def0>,
#  'memo': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0df28>,
#  'seersuckerthursday': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0df60>,
#  'lzagrrtzfl': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0df98>,
#  'vh1': <gensim.models.keyedvectors.Vocab at 0x7fcb78d0dfd0>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10048>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10080>,
#  'petty': <gensim.models.keyedvectors.Vocab at 0x7fcb78d100b8>,
#  'qxdoemfuqo': <gensim.models.keyedvectors.Vocab at 0x7fcb78d100f0>,
#  'mcr6lrjh2h': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10128>,
#  'tuxcedocat': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10160>,
#  'dopefuls': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10198>,
#  '2009': <gensim.models.keyedvectors.Vocab at 0x7fcb78d101d0>,
#  'gloating': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10208>,
#  'abt': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10240>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10278>,
#  'dem': <gensim.models.keyedvectors.Vocab at 0x7fcb78d102b0>,
#  'pols': <gensim.models.keyedvectors.Vocab at 0x7fcb78d102e8>,
#  'bidding': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10320>,
#  '2000s': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10358>,
#  'billionaire': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10390>,
#  'caricature': <gensim.models.keyedvectors.Vocab at 0x7fcb78d103c8>,
#  'myacash': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10400>,
#  '5spmu3csic': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10438>,
#  'peddoc63': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10470>,
#  'carly2016': <gensim.models.keyedvectors.Vocab at 0x7fcb78d104a8>,
#  'flyoverculture': <gensim.models.keyedvectors.Vocab at 0x7fcb78d104e0>,
#  'leahr77': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10518>,
#  'steph93065': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10550>,
#  'maydnusa': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10588>,
#  'daenerys': <gensim.models.keyedvectors.Vocab at 0x7fcb78d105c0>,
#  '3jrcuqdafu': <gensim.models.keyedvectors.Vocab at 0x7fcb78d105f8>,
#  'scorpionspriest': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10630>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10668>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fcb78d106a0>,
#  'hug': <gensim.models.keyedvectors.Vocab at 0x7fcb78d106d8>,
#  'johnfugelsang': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10710>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10748>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10780>,
#  'struggling': <gensim.models.keyedvectors.Vocab at 0x7fcb78d107b8>,
#  'unlimited': <gensim.models.keyedvectors.Vocab at 0x7fcb78d107f0>,
#  'pfikac': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10828>,
#  'verge': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10860>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10898>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x7fcb78d108d0>,
#  'washington': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10908>,
#  'holding': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10940>,
#  'mysa': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10978>,
#  'txlege': <gensim.models.keyedvectors.Vocab at 0x7fcb78d109b0>,
#  'drmartyfox': <gensim.models.keyedvectors.Vocab at 0x7fcb78d109e8>,
#  'drudge': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10a20>,
#  'poll': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10a58>,
#  'pjnet': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10a90>,
#  'yuh6j7qqha': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10ac8>,
#  'siteroi': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10b00>,
#  'governorperry': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10b38>,
#  'fights': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10b70>,
#  'immigration': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10ba8>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10be0>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10c18>,
#  'porous': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10c50>,
#  'fixed': <gensim.models.keyedvectors.Vocab at 0x7fcb78d10c88>,
#  ...}

# %%
model.wv["level"]
# Out:
# array([-0.00663869,  0.03270048, -0.04573761,  0.00846171, -0.00091493,
#         0.03525607, -0.05422912, -0.07259817,  0.05107541,  0.02563571,
#         0.0249094 , -0.04198046,  0.06163323,  0.03075265,  0.0076672 ,
#         0.04028037,  0.031223  ,  0.08223183, -0.02456796,  0.03904928,
#         0.08412605, -0.00568389,  0.01450918, -0.07859356, -0.03413889,
#        -0.01645894, -0.04313166,  0.00285511, -0.00964164,  0.005817  ,
#         0.01314514, -0.04669484, -0.03674173, -0.03681422, -0.02586983,
#         0.01178649,  0.00884517,  0.04247189,  0.03906308,  0.05868449,
#        -0.00012229,  0.00185551, -0.00137145, -0.0148484 ,  0.0151591 ,
#         0.02467288,  0.05637284,  0.0679157 ,  0.00124927, -0.05265822,
#        -0.03457583,  0.05236578,  0.02799514, -0.07372238, -0.01889307,
#         0.00101287,  0.03686753, -0.02493149, -0.00147225, -0.01760936,
#        -0.019974  ,  0.00358625,  0.0068832 , -0.04210886,  0.0249658 ,
#         0.05130089,  0.03025015,  0.00349097, -0.02725302, -0.04584714,
#         0.0126698 ,  0.06318346,  0.07003191, -0.03140174,  0.07186696,
#         0.01551779,  0.01110585,  0.01789483,  0.02153516, -0.00631615,
#         0.00813741, -0.03673809,  0.03948227,  0.04608715, -0.05494459,
#         0.04633815, -0.01202438, -0.00782461, -0.07814719, -0.02525681,
#        -0.02085957, -0.02769478, -0.01790758, -0.0346056 , -0.05512583,
#        -0.00918268,  0.01813627,  0.03889707,  0.00329462,  0.06965335],
#       dtype=float32)

# %%
model.wv.most_similar("level")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('articulate', 0.9950860738754272),
#  ('word', 0.9950450658798218),
#  ('race', 0.9949134588241577),
#  ('boy', 0.9946513772010803),
#  ('decisions', 0.9945707321166992),
#  ('floor', 0.9944626092910767),
#  ('die', 0.9944047927856445),
#  ('body', 0.994365930557251),
#  ('looks', 0.9943300485610962),
#  ('brain', 0.9943031072616577)]

# %%
model.wv.most_similar(positive=['king','woman'], negative= ['man'], topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('fu', 0.979304850101471),
#  ('direct', 0.9784883260726929),
#  ('would', 0.9766030311584473),
#  ('hits', 0.9728028774261475),
#  ('answer', 0.972744345664978)]

# %%
model.wv.doesnt_match(['woman','man','queen','movie'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'man'

# %%
#tokenization
max_features = 1200 #number of the unique words in the corpus
tokenizer = Tokenizer(nb_words=max_features, split = ' ')
tokenizer.fit_on_texts(data['text'].values)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py:180: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
#Creating the input data
X = np.zeros((len(corpus),100)) #Initializing the X matrix with zeros
for i in range(len(corpus)):
    emb = [model.wv[w] for w in corpus[i]] #Create a list of word embeddings of the words in each sentence
    X[i] = np.mean(emb, axis=0)

# %%
le = preprocessing.LabelEncoder()
Y = le.fit_transform(sentiment)

# %%
print(X.shape,Y.shape)
# Out:
# (13871, 100) (13871,)

# %%
#Splitting the data into train data and test data
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (11096, 100) (11096,)
# (2775, 100) (2775,)

# %%
#Printing the size of the train data, train label, test data and test label
print("Shape train data = ",np.shape(X_train))
print("Shape of train label = ",np.shape(Y_train))
print("Shape of test data = ",np.shape(X_test))
print("Shape of test label = ",np.shape(Y_test))
# Out:
# Shape train data =  (11096, 100)
# Shape of train label =  (11096,)
# Shape of test data =  (2775, 100)
# Shape of test label =  (2775,)

# %%
#Tokenization
max_features = 1200 #number of words to keep. 1200 is the number of unique words in the corpus.
tokenizer = Tokenizer(nb_words=max_features, split=' ')
tokenizer.fit_on_texts(data['text'].values)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py:180: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
#unique words and thier count
tokenizer.word_counts
# Out:
# OrderedDict([('nancyleegrahn', 6),
#              ('everyone', 109),
#              ('feel', 62),
#              ('climate', 72),
#              ('change', 84),
#              ('question', 351),
#              ('last', 879),
#              ('night', 903),
#              ('exactly', 22),
#              ('gopdebate', 9048),
#              ('scottwalker', 94),
#              ('catch', 9),
#              ('full', 45),
#              ('scott', 101),
#              ('best', 185),
#              ('lines', 14),
#              ('90', 12),
#              ('seconds', 16),
#              ('walker16', 29),
#              ('http', 3018),
#              ('co', 3633),
#              ('zsff', 1),
#              ('tjmshow', 1),
#              ('mention', 57),
#              ('tamir', 2),
#              ('rice', 2),
#              ('held', 10),
#              ('cleveland', 37),
#              ('wow', 55),
#              ('robgeorge', 1),
#              ('carly', 120),
#              ('fiorina', 144),
#              ('trending', 2),
#              ('hours', 34),
#              ('debate', 1063),
#              ('men', 194),
#              ('completed', 1),
#              ('says', 161),
#              ('danscavino', 18),
#              ('w', 161),
#              ('realdonaldtrump', 1079),
#              ('delivered', 8),
#              ('highest', 12),
#              ('ratings', 142),
#              ('history', 40),
#              ('presidential', 184),
#              ('debates', 174),
#              ('trump2016', 77),
#              ('gregabbott', 3),
#              ('tx', 7),
#              ('tedcruz', 282),
#              ('first', 164),
#              ('day', 96),
#              ('rescind', 3),
#              ('every', 120),
#              ('illegal', 73),
#              ('executive', 15),
#              ('action', 9),
#              ('taken', 18),
#              ('barack', 9),
#              ('obama', 185),
#              ('foxnews', 605),
#              ('warriorwoman91', 4),
#              ('liked', 17),
#              ('happy', 15),
#              ('heard', 44),
#              ('going', 194),
#              ('moderator', 45),
#              ('anymore', 23),
#              ('megynkelly', 667),
#              ('https', 907),
#              ('msnbc', 35),
#              ('live', 92),
#              ('thomasaroberts', 1),
#              ('around', 42),
#              ('2', 201),
#              ('pm', 4),
#              ('et', 12),
#              ('deer', 1),
#              ('headlights', 1),
#              ('lizzwinstead', 6),
#              ('ben', 194),
#              ('carson', 357),
#              ('may', 51),
#              ('brain', 47),
#              ('surgeon', 8),
#              ('performed', 10),
#              ('lobotomy', 2),
#              ('nancyosborne180', 5),
#              ('proved', 27),
#              ('batsask', 26),
#              ('badassteachersa', 6),
#              ('tbats', 5),
#              ('g2ggjy1bjd', 1),
#              ('jgreendc', 1),
#              ('fairness', 1),
#              ('billclinton', 4),
#              ('owns', 4),
#              ('phrase', 3),
#              ('waynedupreeshow', 10),
#              ('woke', 9),
#              ('tweet', 49),
#              ('line', 45),
#              ('via', 195),
#              ('govmikehuckabee', 97),
#              ('6ov5hxhicv', 1),
#              ('reading', 21),
#              ('family', 27),
#              ('comments', 65),
#              ('great', 208),
#              ('giagjpygxz', 1),
#              ('arcticfox2016', 2),
#              ('allenwestrepub', 19),
#              ('dear', 89),
#              ('jebbush', 115),
#              ('notamistake', 9),
#              ('ttfg7kycd9', 1),
#              ('pattonoswalt', 43),
#              ('loved', 45),
#              ('walker', 208),
#              ('mark', 9),
#              ('harmon', 1),
#              ('romantic', 1),
#              ('rival', 1),
#              ('summer', 6),
#              ('school', 13),
#              ('look', 177),
#              ('hey', 91),
#              ('chrischristie', 82),
#              ('exploiting', 1),
#              ('tragedy', 2),
#              ('9', 47),
#              ('11', 33),
#              ('political', 116),
#              ('gain', 6),
#              ('rudygiulianigop', 1),
#              ('thing', 127),
#              ('carolcnn', 5),
#              ('donaldtrump', 135),
#              ('fire', 26),
#              ('women', 348),
#              ('peterbeinasl', 1),
#              ('schaeffer', 1),
#              ('iwf', 1),
#              ('myrkiger', 1),
#              ('weigh', 5),
#              ('johncardillo', 4),
#              ('guess', 40),
#              ('speaking', 162),
#              ('time', 345),
#              ('moderators', 117),
#              ('31', 10),
#              ('7', 33),
#              ('2wsut0c0lx', 1),
#              ('reason', 25),
#              ('comment', 24),
#              ('funny', 44),
#              ('case', 16),
#              ('ignorant', 19),
#              ('gop', 740),
#              ('tcot', 232),
#              ('government', 42),
#              ('working', 29),
#              ('people', 627),
#              ('pamelageller', 12),
#              ('huckabee', 311),
#              ('paying', 13),
#              ('transgender', 10),
#              ('surgery', 4),
#              ('soldiers', 10),
#              ('sailors', 1),
#              ('airmen', 1),
#              ('make', 172),
#              ('country', 144),
#              ('safer', 1),
#              ('ha', 27),
#              ('chucknellis', 13),
#              ('cruz', 450),
#              ('class', 51),
#              ('amp', 1059),
#              ('truth', 127),
#              ('gets', 173),
#              ('vote', 159),
#              ('mchamric', 1),
#              ('teatraitors', 5),
#              ('still', 134),
#              ('clown', 29),
#              ('show', 143),
#              ('glad', 26),
#              ('head', 47),
#              ('trump', 1894),
#              ('helping', 7),
#              ('destroy', 31),
#              ('nwgx8g8jwr', 2),
#              ('erinmallorylong', 3),
#              ('hate', 67),
#              ('planned', 55),
#              ('parenthood', 52),
#              ('thekevinryder', 1),
#              ('vine', 18),
#              ('dabulldawg88', 6),
#              ('xkxvdradce', 1),
#              ('mrpooni', 1),
#              ('fox', 1335),
#              ('news', 909),
#              ('trying', 240),
#              ('convince', 6),
#              ('us', 217),
#              ('young', 16),
#              ('black', 97),
#              ('americans', 75),
#              ('worried', 15),
#              ('isis', 56),
#              ('police', 46),
#              ('terrorism', 56),
#              ('rankings', 3),
#              ('worst', 29),
#              ('performance', 61),
#              ('rubio', 400),
#              ('kasich', 202),
#              ('christie', 179),
#              ('bush', 588),
#              ('paul', 218),
#              ('thebaxterbean', 37),
#              ('abortion', 107),
#              ('ban', 7),
#              ('allows', 2),
#              ('rapist', 4),
#              ('father', 29),
#              ('sue', 4),
#              ('emotional', 4),
#              ('distress', 2),
#              ('rhmvgumuir', 2),
#              ('badger', 2),
#              ('feministabulous', 16),
#              ('competition', 5),
#              ('moved', 4),
#              ('far', 60),
#              ('gay', 64),
#              ('rights', 139),
#              ('worse', 22),
#              ('ever', 105),
#              ('g', 202),
#              ('mch7576', 2),
#              ('pry2qpcwfu', 2),
#              ('hillaryclinton', 147),
#              ('watch', 213),
#              ('bet', 19),
#              ('like', 731),
#              ('donating', 2),
#              ('democrat', 64),
#              ('right', 284),
#              ('pglqcqqgop', 1),
#              ('qp1e', 1),
#              ('fbhw', 1),
#              ('need', 406),
#              ('borrow', 4),
#              ('train', 6),
#              ('horn', 1),
#              ('next', 330),
#              ('little', 74),
#              ('bell', 15),
#              ('wimpy', 1),
#              ('hornmeansyouredone', 1),
#              ('lisavikingstad', 1),
#              ('ted', 169),
#              ('bed', 15),
#              ('keep', 78),
#              ('confusingly', 1),
#              ('sad', 27),
#              ('face', 239),
#              ('refuse', 29),
#              ('social', 131),
#              ('media', 99),
#              ('reaction', 22),
#              ('x6kuvskltf', 1),
#              ('socialmedia', 10),
#              ('ogoyfnyikj', 1),
#              ('winesdaypodcast', 1),
#              ('update', 5),
#              ('tech', 7),
#              ('failures', 2),
#              ('fgglf2j5hu', 1),
#              ('zw35dkuozi', 1),
#              ('amymek', 24),
#              ('torched', 1),
#              ('passed', 7),
#              ('gt', 70),
#              ('candycrowley', 8),
#              ('longer', 16),
#              ('famous', 6),
#              ('assassin', 1),
#              ('congratulations', 6),
#              ('u', 143),
#              ('wi', 12),
#              ('stockwizards3', 1),
#              ('ticket', 12),
#              ('would', 493),
#              ('win', 67),
#              ('landslide', 8),
#              ('seanhannity', 21),
#              ('anncoulter', 10),
#              ('republican', 445),
#              ('potus', 74),
#              ('kvxrdashian', 5),
#              ('jeb', 592),
#              ('fault', 8),
#              ('brother', 25),
#              ('clean', 6),
#              ('mess', 29),
#              ('made', 132),
#              ('ali', 5),
#              ('primary', 49),
#              ('voters', 61),
#              ('none', 36),
#              ('wiser', 2),
#              ('policy', 37),
#              ('plans', 12),
#              ('folks', 30),
#              ('putting', 16),
#              ('forth', 5),
#              ('journalism', 2),
#              ('itsashlyperez', 2),
#              ('listening', 27),
#              ('fetty', 1),
#              ('wap', 1),
#              ('packing', 2),
#              ('true', 78),
#              ('american', 236),
#              ('doesthishashtagexpire', 1),
#              ('mgell', 1),
#              ('cross', 4),
#              ('shrug', 1),
#              ('emoji', 3),
#              ('president', 447),
#              ('business', 31),
#              ('lego', 2),
#              ('movie', 24),
#              ('jamellemybelle', 1),
#              ('meanwhile', 11),
#              ('white', 103),
#              ('house', 25),
#              ('nouuut5hkq', 1),
#              ('rowdygentleman', 1),
#              ('planning', 9),
#              ('drinking', 29),
#              ('game', 57),
#              ('rowdy', 6),
#              ('gentleman', 5),
#              ('brownblaze', 3),
#              ('please', 80),
#              ('kkkorgop', 102),
#              ('yaqyac3uv3', 1),
#              ('thinks', 89),
#              ('criticism', 2),
#              ('misogynistic', 10),
#              ('remarks', 11),
#              ('correctness', 32),
#              ('problem', 77),
#              ('nope', 8),
#              ('pervasive', 1),
#              ('sexism', 27),
#              ('lekarmasucre', 1),
#              ('handled', 9),
#              ('blacklivesmatter', 92),
#              ('8zgdy6lpct', 1),
#              ('palmaceiahome1', 7),
#              ('goal', 8),
#              ('take', 210),
#              ('pave', 2),
#              ('way', 119),
#              ('rino', 14),
#              ('philstockworld', 2),
#              ('chat', 6),
#              ('room', 23),
#              ('futures', 3),
#              ('spy', 7),
#              ('nonfarmpayrolls', 3),
#              ('jobs', 42),
#              ('netflix', 3),
#              ('0k06sf81rq', 2),
#              ('say', 239),
#              ('thanks', 166),
#              ('gov', 61),
#              ('tweeted', 20),
#              ('moment', 48),
#              ('saying', 90),
#              ('purpose', 85),
#              ('military', 167),
#              ('kill', 121),
#              ('break', 148),
#              ('things', 171),
#              ('trans', 19),
#              ('servicemembers', 1),
#              ('ariannahuff', 1),
#              ('yki30j7hho', 2),
#              ('chrisstirewalt', 5),
#              ('big', 140),
#              ('moments', 38),
#              ('randpaul', 143),
#              ('vs', 47),
#              ('kellyfil', 1),
#              ('stylemom', 1),
#              ('hell', 70),
#              ('body', 18),
#              ('parts', 10),
#              ('even', 173),
#              ('foh', 1),
#              ('stop', 77),
#              ('1965', 2),
#              ('wtf', 16),
#              ('rushlimbaugh', 19),
#              ('getting', 70),
#              ('beheaded', 3),
#              ('overseas', 4),
#              ('whether', 14),
#              ('calls', 34),
#              ('rosie', 55),
#              ('donnell', 30),
#              ('fat', 44),
#              ('defend', 19),
#              ('fair', 263),
#              ('balanced', 228),
#              ('name', 50),
#              ('calling', 67),
#              ('juvenile', 2),
#              ('theskysgoneout', 1),
#              ('non', 16),
#              ('christians', 10),
#              ('god', 445),
#              ('questions', 376),
#              ('underline', 1),
#              ('anyone', 270),
#              ('really', 371),
#              ('cares', 12),
#              ('religious', 12),
#              ('minorities', 3),
#              ('chri', 2),
#              ('bipartisanism', 15),
#              ('response', 34),
#              ('pathetic', 15),
#              ('ismxbrrm0h', 1),
#              ('factcheckdotorg', 2),
#              ('said', 346),
#              ('cut', 36),
#              ('fl', 7),
#              ('taxes', 24),
#              ('19b', 1),
#              ('includes', 1),
#              ('cuts', 13),
#              ('estate', 1),
#              ('mandated', 1),
#              ('federal', 10),
#              ('law', 25),
#              ('ht', 35),
#              ('mydaughtersarmy', 8),
#              ('want', 373),
#              ('abortions', 21),
#              ('rbl1t4ipx6', 1),
#              ('karrattipaul', 1),
#              ('join', 24),
#              ('sign', 8),
#              ('death', 21),
#              ('warrant', 10),
#              ('signed', 3),
#              ('wakeupamerica', 30),
#              ('cruzcrew', 39),
#              ('htt', 34),
#              ('p0tus', 5),
#              ('closing', 86),
#              ('statements', 54),
#              ('s15nlillso', 1),
#              ('status', 31),
#              ('single', 54),
#              ('broke', 10),
#              ('goodbye', 9),
#              ('bretbaier', 63),
#              ('chris', 426),
#              ('wallace', 370),
#              ('frankluntz', 65),
#              ('14', 14),
#              ('focus', 50),
#              ('groupers', 3),
#              ('favorable', 4),
#              ('view', 25),
#              ('3', 94),
#              ('saw', 46),
#              ('positively', 1),
#              ('holly', 4),
#              ('renee', 3),
#              ('donation', 7),
#              ('carlyfiorina', 205),
#              ('impressed', 27),
#              ('jlfhfvz7st', 1),
#              ('thejimhughes', 3),
#              ('sending', 8),
#              ('foreign', 23),
#              ('aid', 3),
#              ('places', 6),
#              ('burn', 5),
#              ('flag', 7),
#              ('staberkeley', 2),
#              ('frankthorpnbc', 2),
#              ('rand', 172),
#              ('eye', 10),
#              ('roll', 14),
#              ('hf318qsowd', 2),
#              ('johnkasich', 90),
#              ('scrap', 1),
#              ('iran', 73),
#              ('deal', 52),
#              ('get', 462),
#              ('nuke', 2),
#              ('kasich4us', 18),
#              ('9trzxonlzf', 1),
#              ('decide', 13),
#              ('early', 28),
#              ('come', 65),
#              ('back', 136),
#              ('twitter', 131),
#              ('fulltime', 1),
#              ('gonna', 42),
#              ('wait', 69),
#              ('closer', 3),
#              ('election', 47),
#              ('hooked', 1),
#              ('mspackyetti', 1),
#              ('donald', 426),
#              ('campaign', 58),
#              ('reveals', 8),
#              ('1', 143),
#              ('important', 56),
#              ('trolls', 1),
#              ('real', 185),
#              ('scare', 4),
#              ('eve', 3),
#              ('worry', 14),
#              ('never', 215),
#              ('elected', 28),
#              ('remember', 36),
#              ('george', 16),
#              ('twice', 15),
#              ('agenda', 13),
#              ('promote', 2),
#              ('fired', 15),
#              ('hp', 8),
#              ('run', 83),
#              ('race', 69),
#              ('9k1eujdfo7', 1),
#              ('hlllary', 1),
#              ('oh', 141),
#              ('one', 540),
#              ('hear', 237),
#              ('anything', 61),
#              ('affordable', 12),
#              ('child', 14),
#              ('care', 79),
#              ('families', 28),
#              ('naughtybeyotch', 3),
#              ('wqnsupspkc', 2),
#              ('marthamaccallum', 16),
#              ('billhemmer', 19),
#              ('bill', 29),
#              ('martha', 5),
#              ('team', 20),
#              ('2nd', 30),
#              ('ambush', 6),
#              ('megyn', 248),
#              ('kelly', 190),
#              ('attacking', 20),
#              ('war', 85),
#              ('franklin', 5),
#              ('graham', 19),
#              ('1st', 41),
#              ('encouraging', 3),
#              ('see', 266),
#              ('several', 13),
#              ('candidates', 852),
#              ('express', 6),
#              ('faith', 14),
#              ('son', 15),
#              ('jesus', 50),
#              ('christ', 11),
#              ('c', 92),
#              ('snarkydemo', 2),
#              ('politically', 37),
#              ('correct', 44),
#              ('course', 27),
#              ('trumpspeak', 1),
#              ('let', 159),
#              ('huge', 29),
#              ('asshole', 15),
#              ('message', 20),
#              ('wfk5cmvgin', 1),
#              ('davidcicilline', 1),
#              ('episode', 13),
#              ('apprentice', 10),
#              ('seen', 80),
#              ('luntz', 16),
#              ('go', 238),
#              ('almost', 25),
#              ('reach', 6),
#              ('100', 20),
#              ('happens', 8),
#              ('dial', 6),
#              ('research', 7),
#              ('lolhayley', 1),
#              ('something', 68),
#              ('actual', 22),
#              ('man', 147),
#              ('running', 72),
#              ('wondering', 37),
#              ('could', 119),
#              ('party', 220),
#              ('pay', 37),
#              ('liver', 1),
#              ('transplant', 1),
#              ('playing', 32),
#              ('mtaibbi', 5),
#              ('brandondhowell', 1),
#              ('stafriday', 1),
#              ('1ai9cuz8by', 1),
#              ('unconstitutional', 4),
#              ('order', 86),
#              ('enacted', 1),
#              ('pres', 24),
#              ('oba', 2),
#              ('ronnie2k', 1),
#              ('jcuirk1i1u', 1),
#              ('bruneski', 1),
#              ('upstairs', 1),
#              ('kids', 47),
#              ('many', 156),
#              ('miss', 44),
#              ('gopclowncar', 30),
#              ('todd', 6),
#              ('akin', 2),
#              ('sting', 2),
#              ('backfired', 5),
#              ('republicans', 123),
#              ('standwithpp', 8),
#              ('ekxpfkthqn', 1),
#              ('learjetter', 8),
#              ('digest', 2),
#              ('allowing', 5),
#              ('crazy', 35),
#              ('dwstweets', 39),
#              ('trash', 8),
#              ('ladysandersfarm', 12),
#              ('receive', 6),
#              ('enormous', 2),
#              ('applause', 15),
#              ('horribly', 2),
#              ('answer', 114),
#              ('r4e8tpotd5', 1),
#              ('favorite', 65),
#              ('responses', 10),
#              ('2iqcdrcdlm', 1),
#              ('7tdma3vlm8', 1),
#              ('though', 27),
#              ('super', 24),
#              ('conservative', 63),
#              ('reporter', 6),
#              ('actually', 98),
#              ('interview', 15),
#              ('style', 10),
#              ('kingsthings', 2),
#              ('series', 2),
#              ('minute', 17),
#              ('opportunities', 3),
#              ('avoid', 8),
#              ('answering', 16),
#              ('candidate', 312),
#              ('melissagracey', 1),
#              ('credit', 16),
#              ('joke', 33),
#              ('goes', 24),
#              ('someone', 136),
#              ('else', 191),
#              ('icredssplr', 1),
#              ('reince', 14),
#              ('simply', 14),
#              ('incredible', 5),
#              ('apxm8ao8jf', 2),
#              ('doubled', 2),
#              ('previous', 6),
#              ('record', 52),
#              ('watched', 103),
#              ('katethomas', 1),
#              ('literally', 20),
#              ('got', 227),
#              ('lousy', 3),
#              ('hangover', 37),
#              ('cxch7x', 1),
#              ('dreamer', 1),
#              ('haha', 5),
#              ('saas', 1),
#              ('voxdotcom', 10),
#              ('morning', 57),
#              ('towards', 11),
#              ('factchecked', 1),
#              ('daectmllaj', 1),
#              ('texascruzn', 2),
#              ('1z3vufjzlw', 2),
#              ('zellieimani', 11),
#              ('person', 96),
#              ('tv', 107),
#              ('qlgsxrh5hw', 1),
#              ('marco', 97),
#              ('told', 47),
#              ('yesterday', 30),
#              ('anti', 32),
#              ('bigotry', 6),
#              ('a4eiuettlf', 2),
#              ('cariisie', 1),
#              ('place', 40),
#              ('foolish', 3),
#              ('yet', 44),
#              ('think', 479),
#              ('done', 52),
#              ('crying', 8),
#              ('agai', 1),
#              ('akbarjenkins', 1),
#              ('maybe', 56),
#              ('piven', 2),
#              ('cloward', 2),
#              ('confused', 12),
#              ('pinkard', 2),
#              ('bowden', 2),
#              ('steal', 6),
#              ('cars', 3),
#              ('kevinbaker', 2),
#              ('kevinmkr', 1),
#              ('watching', 334),
#              ('qcmxmu8mlp', 1),
#              ('jrehling', 5),
#              ('pigs', 20),
#              ('save', 13),
#              ('theonlyadult', 1),
#              ('might', 41),
#              ('rip', 11),
#              ('everything', 49),
#              ('caught', 12),
#              ('surprise', 28),
#              ('able', 15),
#              ('recover', 2),
#              ('equilibrium', 1),
#              ('kirahoffy', 1),
#              ('web', 4),
#              ('stream', 11),
#              ('mobile', 3),
#              ('app', 6),
#              ('fail', 20),
#              ('surprised', 24),
#              ('tkpesooezt', 2),
#              ('john', 73),
#              ('helped', 9),
#              ('ohioans', 1),
#              ('create', 11),
#              ('350', 1),
#              ('000', 26),
#              ('new', 117),
#              ('america', 245),
#              ('kbzfbjyp2c', 1),
#              ('help', 67),
#              ('maryknoll', 1),
#              ('sisters', 1),
#              ('replace', 25),
#              ('windows', 1),
#              ('convent', 1),
#              ('fdgxg3vv13', 1),
#              ('catholic', 2),
#              ('gofundme', 1),
#              ('trcot', 1),
#              ('largest', 9),
#              ('audience', 73),
#              ('chip', 9),
#              ('nzync1jrxs', 2),
#              ('started', 14),
#              ('violently', 2),
#              ('69ing', 1),
#              ('cameronesposito', 2),
#              ('ugh', 16),
#              ('guys', 88),
#              ('shut', 29),
#              ('much', 164),
#              ('respect', 43),
#              ('teach', 10),
#              ('future', 66),
#              ('probably', 34),
#              ('safe', 6),
#              ('except', 29),
#              ('attacked', 8),
#              ('congoboy', 1),
#              ('long', 142),
#              ('tiring', 2),
#              ('season', 13),
#              ('shockingly', 3),
#              ('ill', 2),
#              ('informed', 11),
#              ('vtk1k0txi', 1),
#              ('blessed', 18),
#              ('thedemocrats', 16),
#              ('find', 47),
#              ('marcorubio', 119),
#              ('miracle', 2),
#              ('happen', 16),
#              ('grow', 11),
#              ('opportunity', 10),
#              ('lnqhdgtudk', 1),
#              ('mattyiceaz', 13),
#              ('carry', 9),
#              ('state', 78),
#              ('xlnb', 2),
#              ('indication', 1),
#              ('peep', 2),
#              ('bh0chsy5eh', 1),
#              ('smethanie', 4),
#              ('sure', 106),
#              ('tooth', 4),
#              ('fairy', 3),
#              ('agreed', 13),
#              ('teletubbies', 3),
#              ('voted', 10),
#              ('yes', 77),
#              ('caller', 3),
#              ('rush', 30),
#              ('limbaugh', 13),
#              ('lost', 49),
#              ('stinger', 3),
#              ('inc', 4),
#              ('behaviour', 2),
#              ('astonishingly', 1),
#              ('biased', 24),
#              ('economics', 3),
#              ('wins', 51),
#              ('falters', 2),
#              ('exaggerates', 2),
#              ('molloaqhwq', 1),
#              ('knowmorenotless', 1),
#              ('gpnaplang', 1),
#              ('jamesviser', 2),
#              ('huh', 11),
#              ('half', 45),
#              ('clinton', 110),
#              ('charity', 1),
#              ('went', 50),
#              ('clintons', 3),
#              ('bvwrosgwal', 1),
#              ('copolitics', 3),
#              ('hillary2016', 21),
#              ('stophillary', 2),
#              ('uniteb', 1),
#              ('kraig4u', 1),
#              ('wonder', 40),
#              ('took', 49),
#              ('seriously', 73),
#              ('heidil', 2),
#              ('rn', 3),
#              ('diegouk', 1),
#              ('democrats', 101),
#              ('7v4wjok3vm', 1),
#              ('p2', 56),
#              ('ctl', 4),
#              ('topprog', 9),
#              ('tlot', 27),
#              ('owe', 3),
#              ('thank', 57),
#              ('4', 69),
#              ('exposing', 3),
#              ('world', 90),
#              ('rhinos', 3),
#              ('lies', 29),
#              ('budget', 27),
#              ('535m', 1),
#              ('surplus', 4),
#              ('76b', 1),
#              ('deficit', 3),
#              ('vvmxzkxlkr', 1),
#              ('sensanders', 11),
#              ('give', 88),
#              ('birth', 21),
#              ('changed', 30),
#              ('5hkcefp1hf', 1),
#              ('received', 40),
#              ('word', 106),
#              ('soup', 1),
#              ('sandwich', 2),
#              ('frankconniff', 5),
#              ('interviewer', 3),
#              ('talking', 166),
#              ('points', 39),
#              ('feeding', 1),
#              ('lesliemac', 1),
#              ('murder', 5),
#              ('ppl', 30),
#              ('fine', 12),
#              ('unborn', 17),
#              ('babies', 23),
#              ('goplogic', 1),
#              ('missing', 19),
#              ('jon', 32),
#              ('stewaalready', 2),
#              ('jonvoyage', 34),
#              ('h', 36),
#              ('charlottelaws', 1),
#              ('standing', 16),
#              ('libertyjibbet', 1),
#              ('know', 341),
#              ('whine', 7),
#              ('unfair', 14),
#              ('set', 194),
#              ('ya', 20),
#              ('gopde', 37),
#              ('pro', 72),
#              ('life', 141),
#              ('hour', 21),
#              ('forkedtongue', 1),
#              ('iseeorangepeople', 1),
#              ('failed', 35),
#              ('tonight', 327),
#              ('tried', 30),
#              ('destroying', 4),
#              ('kellyfai', 1),
#              ('edstetzer', 3),
#              ('btw', 9),
#              ('mix', 3),
#              ('politics', 93),
#              ('religion', 19),
#              ('teammarco', 5),
#              ('nailed', 10),
#              ('must', 55),
#              ('protect', 14),
#              ('nn6s7do22j', 1),
#              ('bankruptcy', 30),
#              ('giving', 41),
#              ('softball', 124),
#              ('obviously', 169),
#              ('memo', 2),
#              ('seersuckerthursday', 1),
#              ('lzagrrtzfl', 1),
#              ('vh1', 1),
#              ('honestly', 24),
#              ('types', 3),
#              ('petty', 5),
#              ('qxdoemfuqo', 1),
#              ('mcr6lrjh2h', 1),
#              ('tuxcedocat', 1),
#              ('dopefuls', 1),
#              ('2009', 3),
#              ('gloating', 1),
#              ('abt', 19),
#              ('buying', 9),
#              ('dem', 15),
#              ('pols', 1),
#              ('bidding', 1),
#              ('2000s', 1),
#              ('billionaire', 12),
#              ('caricature', 1),
#              ('myacash', 1),
#              ('5spmu3csic', 1),
#              ('peddoc63', 15),
#              ('carly2016', 31),
#              ('flyoverculture', 2),
#              ('leahr77', 3),
#              ('steph93065', 5),
#              ('maydnusa', 6),
#              ('daenerys', 2),
#              ('3jrcuqdafu', 1),
#              ('scorpionspriest', 1),
#              ('telling', 24),
#              ('another', 75),
#              ('hug', 19),
#              ('johnfugelsang', 15),
#              ('missed', 47),
#              ('either', 29),
#              ('struggling', 5),
#              ('unlimited', 2),
#              ('pfikac', 1),
#              ('verge', 1),
#              ('greatest', 15),
#              ('alive', 13),
#              ('washington', 26),
#              ('holding', 14),
#              ('mysa', 1),
#              ('txlege', 3),
#              ('drmartyfox', 3),
#              ('drudge', 34),
#              ('poll', 43),
#              ('pjnet', 38),
#              ('yuh6j7qqha', 1),
#              ('siteroi', 2),
#              ('governorperry', 23),
#              ('fights', 5),
#              ('immigration', 133),
#              ('q', 26),
#              ('border', 20),
#              ('porous', 1),
#              ('fixed', 7),
#              ('summary', 17),
#              ...])

# %%
#dictionary index of a word
tokenizer.word_index["moderators"]
# Out:
# 185

# %%
X = tokenizer.texts_to_sequences(data['text'].values)
X = pad_sequences(X, padding = 'post') #Zero padding at the end of the sequence

# %%
Y = to_categorical(Y)
print(Y)
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]
#  ...
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [0. 0. 1.]]

# %%
#splitting the data as train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import warnings
warnings.filterwarnings('ignore')

# %%
embed_dim = 500
hidden_layer = 100
model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
model.add(Dropout(0.2))
model.add(SimpleRNN(hidden_layer))
model.add(Dense(50))
model.add(Dense(3,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 24, 500)           600000
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 24, 500)           0
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 100)               60100
# _________________________________________________________________
# dense_26 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_27 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 665,303
# Trainable params: 665,303
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train,Y_train,epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.8510 - accuracy: 0.6272
# Epoch 2/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.7263 - accuracy: 0.6874
# Epoch 3/20
# 347/347 [==============================] - 11s 30ms/step - loss: 0.6494 - accuracy: 0.7234
# Epoch 4/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.5877 - accuracy: 0.7551
# Epoch 5/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.5348 - accuracy: 0.7787
# Epoch 6/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.4864 - accuracy: 0.8037
# Epoch 7/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.4572 - accuracy: 0.8161
# Epoch 8/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.4237 - accuracy: 0.8326
# Epoch 9/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3928 - accuracy: 0.8441
# Epoch 10/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3680 - accuracy: 0.8535
# Epoch 11/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3578 - accuracy: 0.8584
# Epoch 12/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3341 - accuracy: 0.8694
# Epoch 13/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3335 - accuracy: 0.8709
# Epoch 14/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3096 - accuracy: 0.8789
# Epoch 15/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.3120 - accuracy: 0.8776
# Epoch 16/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.2902 - accuracy: 0.8849
# Epoch 17/20
# 347/347 [==============================] - 11s 30ms/step - loss: 0.2809 - accuracy: 0.8893
# Epoch 18/20
# 347/347 [==============================] - 11s 30ms/step - loss: 0.2854 - accuracy: 0.8873
# Epoch 19/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.2741 - accuracy: 0.8911
# Epoch 20/20
# 347/347 [==============================] - 10s 30ms/step - loss: 0.2707 - accuracy: 0.8926

# %%
score = model.evaluate(X_test, Y_test, verbose = 1, batch_size = 32)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# 87/87 [==============================] - 1s 7ms/step - loss: 1.2994 - accuracy: 0.6306
# Accuracy: 63.06

# %%
test = data['text'][0]
test = clean_data(test)
test = test.replace('rt ','')
test = [test]
test = tokenizer.texts_to_sequences(test)
test = pad_sequences(test, maxlen=24, padding = 'post')

# %%
class_label = model.predict_classes(test)
print(le.inverse_transform(class_label))
# Out:
# WARNING:tensorflow:From <ipython-input-66-10293262ff95>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ['Neutral']

# %% [markdown]
# **observation:**
#
# i have added more dense layers for increasing the accuracy but after sometime i didnt find any increase in accuracy when compared with the reference code's accuracy.
#
# so. i have added an extra dense layer of 50 neurons and i got an increased accuracy 63.06% which is 1% more than the reference code's accuracy.

# %% [markdown]
# CNN LSTM

# %%
vocabulary_size = len(tokenizer.word_counts)
vocabulary_size
# Out:
# 18553

# %%
embed_dim = 500
model = Sequential()
model.add(Embedding(vocabulary_size, embed_dim,input_length = X.shape[1]))
model.add(Dropout(0.2))
model.add(Conv1D(filters=64,kernel_size=5,padding='valid',activation='relu',strides=1))
model.add(MaxPooling1D(pool_size=4))
model.add(LSTM(50)) #hidden layer neurons = 50
model.add(Dense(vocabulary_size, activation='softmax'))
model.add(Dense(3))
model.add(Activation('softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 24, 500)           9276500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 500)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 20, 64)            160064
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 5, 64)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 50)                23000
# _________________________________________________________________
# dense_1 (Dense)              (None, 18553)             946203
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 55662
# _________________________________________________________________
# activation (Activation)      (None, 3)                 0
# =================================================================
# Total params: 10,461,429
# Trainable params: 10,461,429
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train,Y_train,epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# 347/347 [==============================] - 54s 154ms/step - loss: 0.9527 - accuracy: 0.6109
# Epoch 2/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.8731 - accuracy: 0.6202
# Epoch 3/20
# 347/347 [==============================] - 53s 152ms/step - loss: 0.8181 - accuracy: 0.6514
# Epoch 4/20
# 347/347 [==============================] - 57s 163ms/step - loss: 0.7636 - accuracy: 0.6804
# Epoch 5/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.7125 - accuracy: 0.7118
# Epoch 6/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.6611 - accuracy: 0.7374
# Epoch 7/20
# 347/347 [==============================] - 53s 152ms/step - loss: 0.6196 - accuracy: 0.7611
# Epoch 8/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.5886 - accuracy: 0.7777
# Epoch 9/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.5659 - accuracy: 0.7917
# Epoch 10/20
# 347/347 [==============================] - 53s 152ms/step - loss: 0.5416 - accuracy: 0.8053
# Epoch 11/20
# 347/347 [==============================] - 54s 154ms/step - loss: 0.5089 - accuracy: 0.8216
# Epoch 12/20
# 347/347 [==============================] - 53s 154ms/step - loss: 0.4907 - accuracy: 0.8329
# Epoch 13/20
# 347/347 [==============================] - 53s 154ms/step - loss: 0.4713 - accuracy: 0.8417
# Epoch 14/20
# 347/347 [==============================] - 53s 151ms/step - loss: 0.4564 - accuracy: 0.8477
# Epoch 15/20
# 347/347 [==============================] - 54s 157ms/step - loss: 0.4508 - accuracy: 0.8499
# Epoch 16/20
# 347/347 [==============================] - 58s 168ms/step - loss: 0.4329 - accuracy: 0.8582
# Epoch 17/20
# 347/347 [==============================] - 55s 159ms/step - loss: 0.4221 - accuracy: 0.8604
# Epoch 18/20
# 347/347 [==============================] - 55s 159ms/step - loss: 0.4072 - accuracy: 0.8666
# Epoch 19/20
# 347/347 [==============================] - 54s 156ms/step - loss: 0.3975 - accuracy: 0.8702
# Epoch 20/20
# 347/347 [==============================] - 52s 151ms/step - loss: 0.3901 - accuracy: 0.8720

# %%
score = model.evaluate(X_train, Y_train, verbose = 1, batch_size = 32)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# 347/347 [==============================] - 4s 12ms/step - loss: 0.3743 - accuracy: 0.8810
# Accuracy: 88.10

# %%
score = model.evaluate(X_test, Y_test, verbose = 1, batch_size = 32)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# 87/87 [==============================] - 1s 11ms/step - loss: 0.9512 - accuracy: 0.6537
# Accuracy: 65.37

# %%
test = data['text'][0]
test = clean_data(test)
test = test.replace('rt ','')
test = [test]
test = tokenizer.texts_to_sequences(test)
test = pad_sequences(test, maxlen=24, padding = 'post')

# %%
class_label = model.predict_classes(test)
print(le.inverse_transform(class_label))
# Out:
# ['Negative']

# %% [markdown]
# **observation:**
#
# here i have taken the length of the token_words and added it as an layer "vocabulary size" and used "vocabulary_size" in place of max_features, which i took example from the TRAC2020 D.L model
#
# and i got an accuracy of 65.37% which is 5% more than the refernce code's accuracy.
#
# for more accuracy i experimented with the vocablury size using a reference.
#
# i even tried adding more dense layers but it declined the accuracy to less than 60%.
